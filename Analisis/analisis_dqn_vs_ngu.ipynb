# %%
import gymnasium as gym
from NGU.DQN import DQN as NGU_DQN
from BasicDQN.DQN import DQN as BasicDQN
from stable_baselines3.common.monitor import Monitor
import copy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# c:\Users\juan_\AppData\Local\Programs\Python\Python312\Lib\site-packages\gym\envs\registration.py:307: DeprecationWarning: The package name gym_minigrid has been deprecated in favor of minigrid. Please uninstall gym_minigrid and install minigrid with `pip install minigrid`. Future releases will be maintained under the new package name minigrid.
#   fn()

# %%
# Parámetros comunes
base_params = dict(
    learning_rate = 0.001,
    buffer_size = 1_000_000,
    learning_starts = 1_000,
    batch_size = 128,
    tau = 1.0,
    gamma = 0.99,
    train_freq = 16,
    gradient_steps = 4,
    target_update_interval = 1_000,
    exploration_fraction = 0.1,
    exploration_initial_eps = 0.1,
    exploration_final_eps = 0.1,
    max_grad_norm = 10,
    verbose = 1,
)

# Copias con y sin NGU
# ngu_params = copy.deepcopy(base_params)
# ngu_params["enable_ngu"] = True
# ngu_params["beta_candidates"] = [0.3]

# basic_params = copy.deepcopy(base_params)

# %%
ITERACION_ACTUAL = 3
N_RUNS = 2
TOTAL_TIMESTEPS = 300_000

# %%
for run in range(ITERACION_ACTUAL, ITERACION_ACTUAL + N_RUNS):
    print(f"Ejecutando corrida {run}/{ITERACION_ACTUAL + N_RUNS}")

    # Crear entorno y monitor con nombre único por corrida
    env_basic = Monitor(gym.make("MountainCar-v0"), filename=f"runs_final/monitor_basic_{run}")
    env_ngu = Monitor(gym.make("MountainCar-v0"), filename=f"runs_final/monitor_ngu_{run}")

    # Clonar parámetros
    ngu_params = copy.deepcopy(base_params)
    ngu_params["enable_ngu"] = True
    ngu_params["beta_candidates"] = [0.3]

    basic_params = copy.deepcopy(base_params)

    # Entrenar agentes
    agent_basic = BasicDQN(env_basic, **basic_params)
    agent_basic.learn(total_timesteps=TOTAL_TIMESTEPS)

    agent_ngu = NGU_DQN(env_ngu, **ngu_params)
    agent_ngu.learn(total_timesteps=TOTAL_TIMESTEPS)
# Out:
# Ejecutando corrida 3/5
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 152    |
# |    ep_rew_mean      | -152   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 1000   |
# |    fps              | 1798   |
# |    time_elapsed     | 100    |
# |    total_timesteps  | 181215 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.5411 |
# |    n_updates        | 45052  |
# --------------------------------
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 134    |
# |    ep_rew_mean      | -134   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 1000   |
# |    fps              | 515    |
# |    time_elapsed     | 290    |
# |    total_timesteps  | 149554 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.5403 |
# |    n_updates        | 37140  |
# --------------------------------
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 121    |
# |    ep_rew_mean      | -121   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 2000   |
# |    fps              | 437    |
# |    time_elapsed     | 622    |
# |    total_timesteps  | 272303 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.4170 |
# |    n_updates        | 67824  |
# --------------------------------
# Ejecutando corrida 3/5
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 143    |
# |    ep_rew_mean      | -143   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 1000   |
# |    fps              | 1235   |
# |    time_elapsed     | 137    |
# |    total_timesteps  | 170416 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 1.4381 |
# |    n_updates        | 42356  |
# --------------------------------
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 149    |
# |    ep_rew_mean      | -149   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 1000   |
# |    fps              | 358    |
# |    time_elapsed     | 447    |
# |    total_timesteps  | 160382 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.9903 |
# |    n_updates        | 39844  |
# --------------------------------
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 122    |
# |    ep_rew_mean      | -122   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 2000   |
# |    fps              | 363    |
# |    time_elapsed     | 778    |
# |    total_timesteps  | 283149 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 36.9375 |
# |    n_updates        | 70536  |
# --------------------------------

# %%
n_archivos = 5

basic_rewards = []
ngu_rewards = []

# Leer recompensas
for i in range(0, n_archivos):
    rb = pd.read_csv(f"runs_final/monitor_basic_{i}.monitor.csv", skiprows=1)["r"].values
    rn = pd.read_csv(f"runs_final/monitor_ngu_{i}.monitor.csv", skiprows=1)["r"].values

    basic_rewards.append(rb)
    ngu_rewards.append(rn)

max_len = max(max(len(r) for r in basic_rewards), max(len(r) for r in ngu_rewards))

def pad_to(arr, length):
    return np.pad(arr, (0, length - len(arr)), constant_values=np.nan)

basic_matrix = np.vstack([pad_to(r, max_len) for r in basic_rewards])
ngu_matrix   = np.vstack([pad_to(r, max_len) for r in ngu_rewards])

# Calcular promedios ignorando NaNs
basic_mean = np.nanmean(basic_matrix, axis=0)
ngu_mean = np.nanmean(ngu_matrix, axis=0)

# Graficar
plt.figure(figsize=(10, 5))
plt.plot(basic_mean, label="BasicDQN (promedio)")
plt.plot(ngu_mean, label="NGU_DQN (promedio)")
plt.xlabel("Episodio")
plt.ylabel("Recompensa")
plt.title(f"Recompensa promedio en {n_archivos} corridas en MountainCar-v0")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\juan_\AppData\Local\Temp\ipykernel_15404\3625948685.py:23: RuntimeWarning: Mean of empty slice
#   basic_mean = np.nanmean(basic_matrix, axis=0)

# %%
# # Entornos distintos (con monitores)
# env_ngu = Monitor(gym.make("MountainCar-v0"), filename="monitor_ngu")
# env_basic = Monitor(gym.make("MountainCar-v0"), filename="monitor_basic")

# # Agentes
# agent_ngu = DQN(env_ngu, **ngu_params)
# agent_basic = DQN(env_basic, **basic_params)

# %%
# agent_ngu.learn(total_timesteps=300_000, log_interval=300)
# Out:
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 194    |
# |    ep_rew_mean      | -194   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 300    |
# |    fps              | 976    |
# |    time_elapsed     | 60     |
# |    total_timesteps  | 59212  |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.0019 |
# |    n_updates        | 14552  |
# --------------------------------
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 162    |
# |    ep_rew_mean      | -162   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 600    |
# |    fps              | 986    |
# |    time_elapsed     | 110    |
# |    total_timesteps  | 109316 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.2353 |
# |    n_updates        | 27080  |
# --------------------------------
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 147    |
# |    ep_rew_mean      | -147   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 900    |
# |    fps              | 991    |
# |    time_elapsed     | 155    |
# |    total_timesteps  | 154554 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.6958 |
# |    n_updates        | 38388  |
# --------------------------------
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 116    |
# |    ep_rew_mean      | -116   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 1200   |
# |    fps              | 998    |
# |    time_elapsed     | 192    |
# |    total_timesteps  | 191984 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.1411 |
# |    n_updates        | 47748  |
# --------------------------------
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 121    |
# |    ep_rew_mean      | -121   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 1500   |
# |    fps              | 1004   |
# |    time_elapsed     | 226    |
# |    total_timesteps  | 227006 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.0368 |
# |    n_updates        | 56500  |
# --------------------------------
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 127    |
# |    ep_rew_mean      | -127   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 1800   |
# |    fps              | 1003   |
# |    time_elapsed     | 263    |
# |    total_timesteps  | 264281 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.6111 |
# |    n_updates        | 65820  |
# --------------------------------

# %%
# agent_basic.learn(total_timesteps=300_000, log_interval=300)
# Out:
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 200    |
# |    ep_rew_mean      | -200   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 300    |
# |    fps              | 1431   |
# |    time_elapsed     | 41     |
# |    total_timesteps  | 59664  |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.0001 |
# |    n_updates        | 14668  |
# --------------------------------
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 200    |
# |    ep_rew_mean      | -200   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 600    |
# |    fps              | 1459   |
# |    time_elapsed     | 81     |
# |    total_timesteps  | 119648 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.0003 |
# |    n_updates        | 29664  |
# --------------------------------
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 199    |
# |    ep_rew_mean      | -199   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 900    |
# |    fps              | 1482   |
# |    time_elapsed     | 121    |
# |    total_timesteps  | 179383 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.6270 |
# |    n_updates        | 44596  |
# --------------------------------
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 195    |
# |    ep_rew_mean      | -195   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 1200   |
# |    fps              | 1499   |
# |    time_elapsed     | 158    |
# |    total_timesteps  | 238456 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.0003 |
# |    n_updates        | 59364  |
# --------------------------------
# --------------------------------
# | rollout/            |        |
# |    ep_len_mean      | 179    |
# |    ep_rew_mean      | -179   |
# |    exploration_rate | 0.100  |
# | time/               |        |
# |    episodes         | 1500   |
# |    fps              | 1505   |
# |    time_elapsed     | 195    |
# |    total_timesteps  | 294179 |
# | train/              |        |
# |    learning_rate    | 0.001  |
# |    loss             | 0.0053 |
# |    n_updates        | 73296  |
# --------------------------------

# %%
# # Cargar datos desde los archivos monitor
# monitor_basic = pd.read_csv("monitor_basic.monitor.csv", skiprows=1)
# monitor_ngu = pd.read_csv("monitor_ngu.monitor.csv", skiprows=1)

# # Graficar recompensas
# plt.figure(figsize=(12, 5))
# plt.plot(monitor_basic["r"], label="BasicDQN")
# plt.plot(monitor_ngu["r"], label="NGU_DQN")
# plt.title("Recompensa por Episodio (desde Monitor)")
# plt.xlabel("Episodio")
# plt.ylabel("Recompensa")
# plt.legend()
# plt.grid(True)

# plt.tight_layout()
# plt.show()

# %%
# plt.figure(figsize=(12, 5))
# plt.plot(monitor_basic["l"], label="BasicDQN")
# plt.plot(monitor_ngu["l"], label="NGU_DQN")
# plt.title("Duración del Episodio (desde Monitor)")
# plt.xlabel("Episodio")
# plt.ylabel("Longitud")
# plt.legend()
# plt.grid(True)

# plt.tight_layout()
# plt.show()
