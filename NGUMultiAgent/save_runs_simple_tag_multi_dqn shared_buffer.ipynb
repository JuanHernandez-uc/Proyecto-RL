# %%
import numpy as np
import random
import torch
import torch.nn as nn
from collections import deque
from mpe2 import simple_tag_v3
import supersuit as ss

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F
import random
from collections import deque
import numpy as np
import time

class MLP(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_dim=128):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, x):
        return self.net(x)


class ReplayBuffer:
    def __init__(self, size):
        self.buffer = deque(maxlen=size)

    def add(self, *transition):
        self.buffer.append(transition)

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        return (
            torch.as_tensor(np.stack(states), dtype=torch.float32),
            torch.as_tensor(actions, dtype=torch.long),
            torch.as_tensor(rewards, dtype=torch.float32),
            torch.as_tensor(np.stack(next_states), dtype=torch.float32),
            torch.as_tensor(dones, dtype=torch.float32)
        )

    def __len__(self):
        return len(self.buffer)


class DQN:
    def __init__(self,
            env,
            learning_rate = 1e-3,
            buffer_size = 300000,
            learning_starts = 100,
            batch_size = 32,
            tau = 1.0,
            gamma = 0.99,
            train_freq = 4,
            gradient_steps = 1,
            target_update_interval = 10000,
            exploration_fraction = 0.1,
            exploration_initial_eps = 1.0,
            exploration_final_eps = 0.05,
            max_grad_norm = 10,
            verbose = 0
        ):
        
        self.env = env
        self.device = torch.device("mps" if torch.mps.is_available() else "cpu")
        example_agent = env.agents[0]
        self.obs_dim = env.observation_space(example_agent).shape[0]
        self.n_actions = env.action_space(example_agent).n

        self.policy = MLP(self.obs_dim, self.n_actions).to(self.device)
        self.target_policy = MLP(self.obs_dim, self.n_actions).to(self.device)
        self.target_policy.load_state_dict(self.policy.state_dict())
        self.target_policy.eval()

        self.optimizer = optim.Adam(self.policy.parameters(), lr=learning_rate, betas=(0.9, 0.999))
        self.replay_buffer = ReplayBuffer(buffer_size)

        self.learning_starts = learning_starts
        self.batch_size = batch_size
        self.tau = tau
        self.gamma = gamma
        self.train_freq = train_freq
        self.gradient_steps = gradient_steps
        self.target_update_interval = target_update_interval
        self.exploration_initial_eps = exploration_initial_eps
        self.exploration_final_eps = exploration_final_eps
        self.exploration_fraction = exploration_fraction
        self.max_grad_norm = max_grad_norm
        self.verbose = verbose

        self.epsilon = self.exploration_initial_eps
        self.last_loss = None
        self.num_updates = 0


    def _select_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.n_actions)
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        with torch.no_grad():
            act_values = self.policy(state)
        return torch.argmax(act_values[0]).item()

    def _train_step(self):
        if len(self.replay_buffer) < self.batch_size:
            return

        self.policy.train()

        total_loss = 0
        for _ in range(self.gradient_steps):
            states, actions, rewards, next_states, dones = self.replay_buffer.sample(self.batch_size)
            states = states.to(self.device)
            actions = actions.to(self.device)
            rewards = rewards.to(self.device)
            next_states = next_states.to(self.device)
            dones = dones.to(self.device)

            q_values = self.policy(states).gather(1, actions.unsqueeze(1)).squeeze(1)

            with torch.no_grad():
                next_q_values = self.target_policy(next_states).max(1)[0]
                expected_q = rewards + self.gamma * next_q_values * (1 - dones)

            loss = F.smooth_l1_loss(q_values, expected_q)
            self.last_loss = loss.item()

            self.optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
            self.optimizer.step()

            self.num_updates += 1

            total_loss += loss.item()
        
        return total_loss / self.gradient_steps

    def learn(self, total_timesteps, log_interval=1000):
        obs, _ = self.env.reset()
        state = np.asarray(obs, dtype=np.float32)
        start_t  = time.perf_counter()
        ep_count = 0
        ep_lens  = deque(maxlen=100)
        ep_rews  = deque(maxlen=100)
        episode_reward = 0
        eps_decay_steps = int(self.exploration_fraction * total_timesteps)

        for t in range(1, total_timesteps + 1):
            self.total_timesteps = t
            self.epsilon = max(
                self.exploration_final_eps,
                self.exploration_initial_eps - (self.exploration_initial_eps - self.exploration_final_eps) * (t / eps_decay_steps)
            )

            action = self._select_action(state)
            next_state, reward, terminated, truncated, info = self.env.step(action)
            #reward = np.clip(reward, -1.0, 1.0)
            done = terminated or truncated
            next_state = np.asarray(next_state, dtype=np.float32)
            self.replay_buffer.add(state, action, reward, next_state, float(done))
            state = next_state
            episode_reward += reward

            if "episode" in info:
                ep_len = info["episode"]["l"]
                ep_rew = info["episode"]["r"]
                ep_lens.append(ep_len)
                ep_rews.append(ep_rew)
                ep_count += 1

            ## Fin del episodio
            if done:
                last_ep_reward = episode_reward
                obs, _ = self.env.reset()
                state = np.asarray(obs, dtype=np.float32)
                episode_reward = 0

            ## Cuándo se entrena la red
            if t > self.learning_starts and t % self.train_freq == 0:
                self._train_step()

            ## Sincronización de red target
            if self.num_updates > 0 and self.num_updates % self.target_update_interval == 0:
                self.target_policy.load_state_dict(self.policy.state_dict())
                self.target_policy.eval()

            if self.verbose and ep_count > 0 and ep_count % log_interval == 0 and done:
                fps = int(t / (time.perf_counter() - start_t))
                lr = self.optimizer.param_groups[0]["lr"]
                loss = self.last_loss if self.last_loss is not None else float("nan")
                print("----------------------------------")
                print(f"| rollout/            |          |")
                print(f"|    ep_len_mean      | {np.mean(ep_lens) if ep_lens else float('nan'):.0f}")
                print(f"|    ep_rew_mean      | {np.mean(ep_rews) if ep_rews else float('nan'):.0f}")
                print(f"|    exploration_rate | {self.epsilon:.3f}")
                print(f"| time/               |          |")
                print(f"|    episodes         | {ep_count}")
                print(f"|    fps              | {fps}")
                print(f"|    time_elapsed     | {int(time.perf_counter() - start_t)}")
                print(f"|    total_timesteps  | {t}")
                print(f"| train/              |          |")
                print(f"|    learning_rate    | {lr:.3g}")
                print(f"|    loss             | {loss:.4f}")
                print(f"|    n_updates        | {self.num_updates}")
                print("----------------------------------")

# %%
def learn_multiagent(env, agent_dict, total_timesteps, log_interval=1000):
    observations, _ = env.reset()
    episode_reward = {agent: 0 for agent in env.agents}
    ep_lens = deque(maxlen=100)
    ep_len = 0
    ep_rews = {agent: deque(maxlen=100) for agent in agent_dict}
    ep_count = 0
    t = 0
    start_t = time.perf_counter()

    eps_decay_steps = int(list(agent_dict.values())[0].exploration_fraction * total_timesteps)

    episode_rewards = []
    losses = []

    last_logged = -1

    while t < total_timesteps:
        actions = {}

        total_rewards = {agent: 0 for agent in env.agents}
        total_losses = {agent: 0 for agent in env.agents}

        for agent in env.agents:
            if agent in agent_dict:
                dqn = agent_dict[agent]
                dqn.epsilon = max(
                    dqn.exploration_final_eps,
                    dqn.exploration_initial_eps - (dqn.exploration_initial_eps - dqn.exploration_final_eps) * (t / eps_decay_steps)
                )
                action = dqn._select_action(observations[agent])
                actions[agent] = action
            else:
                actions[agent] = 0  # good agent se queda quieto

        next_obs, rewards, terminations, truncations, infos = env.step(actions)

        for agent in agent_dict:
            done = terminations[agent] or truncations[agent]
            dqn = agent_dict[agent]

            dqn.replay_buffer.add(
                np.array(observations[agent], dtype=np.float32),
                actions[agent],
                rewards[agent],
                np.array(next_obs[agent], dtype=np.float32),
                float(done)
            )
            episode_reward[agent] += rewards[agent]

            if t > dqn.learning_starts and t % dqn.train_freq == 0:
                loss = dqn._train_step()
                total_losses[agent] += loss if loss is not None else 0

            if dqn.num_updates > 0 and dqn.num_updates % dqn.target_update_interval == 0:
                dqn.target_policy.load_state_dict(dqn.policy.state_dict())
                dqn.target_policy.eval()

        losses.append(total_losses)

        t += 1
        observations = next_obs
        ep_len += 1
        # Fin de episodio
        if terminations["agent_0"] or truncations["agent_0"]:
            episode_rewards.append(episode_reward.copy())

            for agent in agent_dict:
                ep_rews[agent].append(episode_reward[agent])
                episode_reward[agent] = 0
            
            ep_lens.append(ep_len)  # si no tienes env.env_done_step puedes usar len(env.dones)
            ep_len = 0
            observations, _ = env.reset()
            ep_count += 1

        # Logging
        if ep_count > 0 and ep_count % log_interval == 0 and ep_count != last_logged:
            last_logged = ep_count
            fps = int(t / (time.perf_counter() - start_t))
            print("----------------------------------")
            print(f"| time/               |          |")
            print(f"|    episodes         | {ep_count}")
            print(f"|    fps              | {fps}")
            print(f"|    time_elapsed     | {int(time.perf_counter() - start_t)}")
            print(f"|    total_timesteps  | {t}")
            print(f"|    ep_len_mean      | {np.mean(ep_lens) if ep_lens else float('nan'):.0f}")
            for agent in agent_dict:
                dqn = agent_dict[agent]
                loss = dqn.last_loss if dqn.last_loss is not None else float("nan")
                print(f"| {agent} -> mean_ep_rew | {np.mean(ep_rews[agent]):.2f} | loss: {loss:.4f} | eps: {dqn.epsilon:.3f}")
            print("----------------------------------")

    return episode_rewards, losses

# %%
import matplotlib.pyplot as plt

def plot_total_rewards(rewards_dict_per_episode):
    """
    rewards_dict_per_episode: list de dicts por episodio, ej:
    [{agent_0: 10, agent_1: 12}, {agent_0: 5, agent_1: 7}, ...]
    """

    # llevar a cpu
    agent_names = rewards_dict_per_episode[0].keys()
    episode_count = len(rewards_dict_per_episode)

    for agent in agent_names:
        rewards = [episode[agent].cpu().item() if torch.is_tensor(episode[agent]) else episode[agent] for episode in rewards_dict_per_episode]
        plt.plot(rewards, label=agent)

    plt.xlabel("Episodio")
    plt.ylabel("Reward total por agente")
    plt.title("Recompensas por episodio")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import pandas as pd

# %%
# Crear entorno paralelo
seed = 42
env = simple_tag_v3.parallel_env(render_mode='rgb_array', num_good=1, num_adversaries=3, num_obstacles=0, max_cycles=150, dynamic_rescaling = True)
env.reset(seed=seed)
agents = env.agents

dqn_params = {
    "learning_rate": 1e-3,
    "buffer_size": 1000000,
    "learning_starts": 5000,
    "batch_size": 128,
    "tau": 1.0,
    "gamma": 0.99,
    "train_freq": 16,
    "gradient_steps": 4,
    "target_update_interval": 2000,
    "exploration_fraction": 0.1,
    "exploration_initial_eps": 1,
    "exploration_final_eps": 0.1,
    "max_grad_norm": 10,
    "verbose": 1,
}

# Inicializar agentes solo para los adversarios
for i in range(1, 16):
    agent_dict = {
        agent: DQN(env, **dqn_params)
        for agent in agents if agent.startswith("adversary")
    }

    # Compartir replay buffer
    #-------------
    shared_buffer = agent_dict["adversary_0"].replay_buffer
    for name in agent_dict:
        agent_dict[name].replay_buffer = shared_buffer
    #-------------

    # Entrenar los agentes adversarios
    episode_rewards, episode_losses = learn_multiagent(env, agent_dict, total_timesteps=200000, log_interval=100)

    filename = f"runs_multi_dqn_replay_buffer/multi_dqn_replay_buffer_run_{i}.csv"
    cleaned_log = []

    for ep_idx, ep in enumerate(episode_rewards):
        row = {"episode": ep_idx}

        for agent, value in ep.items():
            if torch.is_tensor(value):
                value = value.cpu().item()
            row[agent] = value

        cleaned_log.append(row)

    # Crear DataFrame
    df = pd.DataFrame(cleaned_log)
    df.to_csv(filename, index=False)
# Out:
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 412
# |    time_elapsed     | 36
# |    total_timesteps  | 15000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 9.60 | loss: 0.0006 | eps: 0.325
# | adversary_1 -> mean_ep_rew | 9.60 | loss: 0.0002 | eps: 0.325
# | adversary_2 -> mean_ep_rew | 9.60 | loss: 0.0747 | eps: 0.325
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 313
# |    time_elapsed     | 95
# |    total_timesteps  | 30000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 5.30 | loss: 0.0762 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.30 | loss: 0.0016 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.30 | loss: 0.2311 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 288
# |    time_elapsed     | 156
# |    total_timesteps  | 45000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 5.20 | loss: 0.0015 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.20 | loss: 0.0752 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.20 | loss: 0.1428 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 275
# |    time_elapsed     | 217
# |    total_timesteps  | 60000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 6.70 | loss: 0.0744 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.70 | loss: 0.0742 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.70 | loss: 0.0756 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 266
# |    time_elapsed     | 281
# |    total_timesteps  | 75000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 10.20 | loss: 0.0050 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 10.20 | loss: 0.1494 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 10.20 | loss: 0.0154 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 255
# |    time_elapsed     | 351
# |    total_timesteps  | 90000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 13.50 | loss: 0.2776 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 13.50 | loss: 0.0101 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 13.50 | loss: 0.0077 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 246
# |    time_elapsed     | 425
# |    total_timesteps  | 105000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 33.10 | loss: 0.2547 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 33.10 | loss: 0.1607 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 33.10 | loss: 0.0186 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 236
# |    time_elapsed     | 508
# |    total_timesteps  | 120000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 85.10 | loss: 0.1992 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 85.10 | loss: 0.0457 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 85.10 | loss: 0.1804 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 227
# |    time_elapsed     | 592
# |    total_timesteps  | 135000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 136.40 | loss: 0.3165 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 136.40 | loss: 0.5034 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 136.40 | loss: 0.0329 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 220
# |    time_elapsed     | 680
# |    total_timesteps  | 150000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 222.70 | loss: 0.4123 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 222.70 | loss: 0.3232 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 222.70 | loss: 0.3666 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 213
# |    time_elapsed     | 772
# |    total_timesteps  | 165000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 302.30 | loss: 0.3858 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 302.30 | loss: 0.4388 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 302.30 | loss: 0.2368 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 207
# |    time_elapsed     | 869
# |    total_timesteps  | 180000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 330.40 | loss: 0.6468 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 330.40 | loss: 0.3436 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 330.40 | loss: 0.3942 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 200
# |    time_elapsed     | 970
# |    total_timesteps  | 195000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 400.40 | loss: 0.5268 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 400.40 | loss: 0.7297 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 400.40 | loss: 0.9852 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 451
# |    time_elapsed     | 33
# |    total_timesteps  | 15000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 11.50 | loss: 0.0006 | eps: 0.325
# | adversary_1 -> mean_ep_rew | 11.50 | loss: 0.0739 | eps: 0.325
# | adversary_2 -> mean_ep_rew | 11.50 | loss: 0.0743 | eps: 0.325
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 319
# |    time_elapsed     | 93
# |    total_timesteps  | 30000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 7.20 | loss: 0.0744 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.20 | loss: 0.1524 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.20 | loss: 0.1528 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 290
# |    time_elapsed     | 154
# |    total_timesteps  | 45000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 5.80 | loss: 0.0754 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.80 | loss: 0.0103 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.80 | loss: 0.2221 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 276
# |    time_elapsed     | 216
# |    total_timesteps  | 60000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 10.40 | loss: 0.1501 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 10.40 | loss: 0.0786 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 10.40 | loss: 0.0865 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 266
# |    time_elapsed     | 281
# |    total_timesteps  | 75000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 15.00 | loss: 0.0781 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 15.00 | loss: 0.0045 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 15.00 | loss: 0.0116 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 257
# |    time_elapsed     | 349
# |    total_timesteps  | 90000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 73.60 | loss: 0.2242 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 73.60 | loss: 0.2054 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 73.60 | loss: 0.1306 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 248
# |    time_elapsed     | 423
# |    total_timesteps  | 105000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 91.20 | loss: 0.3362 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 91.20 | loss: 0.0219 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 91.20 | loss: 0.3270 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 238
# |    time_elapsed     | 502
# |    total_timesteps  | 120000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 118.10 | loss: 0.5121 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 118.10 | loss: 0.3105 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 118.10 | loss: 0.0761 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 229
# |    time_elapsed     | 589
# |    total_timesteps  | 135000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 134.30 | loss: 0.0362 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 134.30 | loss: 0.5077 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 134.30 | loss: 0.2260 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 219
# |    time_elapsed     | 683
# |    total_timesteps  | 150000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 170.80 | loss: 0.6033 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 170.80 | loss: 0.6575 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 170.80 | loss: 0.2259 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 211
# |    time_elapsed     | 778
# |    total_timesteps  | 165000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 192.00 | loss: 0.5673 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 192.00 | loss: 0.2184 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 192.00 | loss: 0.3390 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 205
# |    time_elapsed     | 877
# |    total_timesteps  | 180000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 242.90 | loss: 0.4430 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 242.90 | loss: 0.3928 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 242.90 | loss: 0.9248 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 198
# |    time_elapsed     | 980
# |    total_timesteps  | 195000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 291.40 | loss: 1.1955 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 291.40 | loss: 0.4727 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 291.40 | loss: 0.8456 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 432
# |    time_elapsed     | 34
# |    total_timesteps  | 15000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 11.60 | loss: 0.0753 | eps: 0.325
# | adversary_1 -> mean_ep_rew | 11.60 | loss: 0.0726 | eps: 0.325
# | adversary_2 -> mean_ep_rew | 11.60 | loss: 0.0748 | eps: 0.325
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 319
# |    time_elapsed     | 94
# |    total_timesteps  | 30000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 7.70 | loss: 0.0031 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.70 | loss: 0.1460 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.70 | loss: 0.0007 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 289
# |    time_elapsed     | 155
# |    total_timesteps  | 45000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 7.30 | loss: 0.0658 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.30 | loss: 0.0753 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.30 | loss: 0.0007 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 273
# |    time_elapsed     | 218
# |    total_timesteps  | 60000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 10.50 | loss: 0.0690 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 10.50 | loss: 0.0025 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 10.50 | loss: 0.1183 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 262
# |    time_elapsed     | 285
# |    total_timesteps  | 75000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 22.60 | loss: 0.0985 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 22.60 | loss: 0.0758 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 22.60 | loss: 0.0120 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 253
# |    time_elapsed     | 355
# |    total_timesteps  | 90000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 106.70 | loss: 0.2907 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 106.70 | loss: 0.0702 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 106.70 | loss: 0.3451 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 244
# |    time_elapsed     | 429
# |    total_timesteps  | 105000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 219.70 | loss: 0.6965 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 219.70 | loss: 0.3344 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 219.70 | loss: 0.6024 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 234
# |    time_elapsed     | 510
# |    total_timesteps  | 120000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 323.40 | loss: 0.3758 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 323.40 | loss: 0.9679 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 323.40 | loss: 0.8064 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 226
# |    time_elapsed     | 596
# |    total_timesteps  | 135000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 311.00 | loss: 0.8448 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 311.00 | loss: 1.0130 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 311.00 | loss: 0.5417 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 218
# |    time_elapsed     | 686
# |    total_timesteps  | 150000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 389.60 | loss: 1.1718 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 389.60 | loss: 1.4943 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 389.60 | loss: 0.7433 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 211
# |    time_elapsed     | 780
# |    total_timesteps  | 165000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 459.90 | loss: 1.1638 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 459.90 | loss: 1.8204 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 459.90 | loss: 1.1672 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 204
# |    time_elapsed     | 879
# |    total_timesteps  | 180000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 530.80 | loss: 1.7617 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 530.80 | loss: 1.3463 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 530.80 | loss: 2.2134 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 198
# |    time_elapsed     | 983
# |    total_timesteps  | 195000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 553.00 | loss: 1.7784 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 553.00 | loss: 2.6262 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 553.00 | loss: 1.2381 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 432
# |    time_elapsed     | 34
# |    total_timesteps  | 15000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 7.90 | loss: 0.0003 | eps: 0.325
# | adversary_1 -> mean_ep_rew | 7.90 | loss: 0.0756 | eps: 0.325
# | adversary_2 -> mean_ep_rew | 7.90 | loss: 0.0006 | eps: 0.325
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 320
# |    time_elapsed     | 93
# |    total_timesteps  | 30000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 6.50 | loss: 0.0750 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.50 | loss: 0.0757 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.50 | loss: 0.0747 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 287
# |    time_elapsed     | 156
# |    total_timesteps  | 45000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 7.80 | loss: 0.0019 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.80 | loss: 0.0693 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.80 | loss: 0.0819 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 272
# |    time_elapsed     | 220
# |    total_timesteps  | 60000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 5.80 | loss: 0.0011 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.80 | loss: 0.1498 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.80 | loss: 0.0031 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 261
# |    time_elapsed     | 286
# |    total_timesteps  | 75000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 7.20 | loss: 0.1659 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.20 | loss: 0.0061 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.20 | loss: 0.0064 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 252
# |    time_elapsed     | 356
# |    total_timesteps  | 90000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 21.20 | loss: 0.0084 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 21.20 | loss: 0.2204 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 21.20 | loss: 0.0917 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 243
# |    time_elapsed     | 431
# |    total_timesteps  | 105000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 45.60 | loss: 0.0306 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 45.60 | loss: 0.0848 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 45.60 | loss: 0.1568 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 234
# |    time_elapsed     | 512
# |    total_timesteps  | 120000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 83.10 | loss: 0.4639 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 83.10 | loss: 0.5426 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 83.10 | loss: 0.0866 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 225
# |    time_elapsed     | 597
# |    total_timesteps  | 135000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 150.10 | loss: 0.3572 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 150.10 | loss: 0.1574 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 150.10 | loss: 0.2528 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 218
# |    time_elapsed     | 687
# |    total_timesteps  | 150000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 210.20 | loss: 0.4630 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 210.20 | loss: 0.1712 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 210.20 | loss: 0.2687 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 210
# |    time_elapsed     | 782
# |    total_timesteps  | 165000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 322.60 | loss: 0.5324 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 322.60 | loss: 0.3989 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 322.60 | loss: 0.4508 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 204
# |    time_elapsed     | 881
# |    total_timesteps  | 180000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 285.50 | loss: 0.7883 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 285.50 | loss: 0.7136 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 285.50 | loss: 0.6116 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 198
# |    time_elapsed     | 984
# |    total_timesteps  | 195000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 358.60 | loss: 0.8577 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 358.60 | loss: 0.9044 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 358.60 | loss: 0.9964 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 435
# |    time_elapsed     | 34
# |    total_timesteps  | 15000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 9.00 | loss: 0.0004 | eps: 0.325
# | adversary_1 -> mean_ep_rew | 9.00 | loss: 0.0742 | eps: 0.325
# | adversary_2 -> mean_ep_rew | 9.00 | loss: 0.1466 | eps: 0.325
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 320
# |    time_elapsed     | 93
# |    total_timesteps  | 30000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 7.50 | loss: 0.0005 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.50 | loss: 0.0765 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.50 | loss: 0.0721 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 289
# |    time_elapsed     | 155
# |    total_timesteps  | 45000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 5.20 | loss: 0.0012 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.20 | loss: 0.0016 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.20 | loss: 0.1425 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 274
# |    time_elapsed     | 218
# |    total_timesteps  | 60000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 7.70 | loss: 0.0056 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.70 | loss: 0.0779 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.70 | loss: 0.0019 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 263
# |    time_elapsed     | 285
# |    total_timesteps  | 75000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 20.10 | loss: 0.0790 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 20.10 | loss: 0.0781 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 20.10 | loss: 0.0521 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 253
# |    time_elapsed     | 354
# |    total_timesteps  | 90000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 51.70 | loss: 0.0791 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 51.70 | loss: 0.0034 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 51.70 | loss: 0.1678 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 244
# |    time_elapsed     | 429
# |    total_timesteps  | 105000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 180.20 | loss: 0.1562 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 180.20 | loss: 0.0138 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 180.20 | loss: 0.4087 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 235
# |    time_elapsed     | 509
# |    total_timesteps  | 120000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 235.20 | loss: 0.3268 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 235.20 | loss: 0.3357 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 235.20 | loss: 0.4407 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 226
# |    time_elapsed     | 595
# |    total_timesteps  | 135000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 408.10 | loss: 0.6476 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 408.10 | loss: 0.5456 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 408.10 | loss: 1.3909 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 218
# |    time_elapsed     | 687
# |    total_timesteps  | 150000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 385.70 | loss: 0.8676 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 385.70 | loss: 0.9322 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 385.70 | loss: 0.6636 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 210
# |    time_elapsed     | 783
# |    total_timesteps  | 165000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 447.30 | loss: 1.5515 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 447.30 | loss: 1.1107 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 447.30 | loss: 1.3831 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 204
# |    time_elapsed     | 881
# |    total_timesteps  | 180000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 527.00 | loss: 1.2972 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 527.00 | loss: 1.8184 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 527.00 | loss: 1.2423 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 198
# |    time_elapsed     | 984
# |    total_timesteps  | 195000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 582.30 | loss: 2.2878 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 582.30 | loss: 1.8276 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 582.30 | loss: 2.3327 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 435
# |    time_elapsed     | 34
# |    total_timesteps  | 15000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 10.70 | loss: 0.2127 | eps: 0.325
# | adversary_1 -> mean_ep_rew | 10.70 | loss: 0.0003 | eps: 0.325
# | adversary_2 -> mean_ep_rew | 10.70 | loss: 0.0744 | eps: 0.325
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 324
# |    time_elapsed     | 92
# |    total_timesteps  | 30000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 6.70 | loss: 0.0011 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.70 | loss: 0.2234 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.70 | loss: 0.0738 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 294
# |    time_elapsed     | 152
# |    total_timesteps  | 45000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 8.80 | loss: 0.0028 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.80 | loss: 0.0031 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.80 | loss: 0.0010 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 278
# |    time_elapsed     | 215
# |    total_timesteps  | 60000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 14.00 | loss: 0.0060 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 14.00 | loss: 0.3060 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 14.00 | loss: 0.0081 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 267
# |    time_elapsed     | 280
# |    total_timesteps  | 75000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 22.70 | loss: 0.0784 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 22.70 | loss: 0.1591 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 22.70 | loss: 0.1543 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 257
# |    time_elapsed     | 349
# |    total_timesteps  | 90000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 67.90 | loss: 0.3111 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 67.90 | loss: 0.0763 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 67.90 | loss: 0.0715 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 248
# |    time_elapsed     | 422
# |    total_timesteps  | 105000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 133.40 | loss: 0.3960 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 133.40 | loss: 0.2321 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 133.40 | loss: 0.1277 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 238
# |    time_elapsed     | 502
# |    total_timesteps  | 120000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 236.20 | loss: 0.3415 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 236.20 | loss: 0.5770 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 236.20 | loss: 0.4496 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 229
# |    time_elapsed     | 587
# |    total_timesteps  | 135000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 320.10 | loss: 0.7113 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 320.10 | loss: 0.9456 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 320.10 | loss: 0.6848 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 221
# |    time_elapsed     | 676
# |    total_timesteps  | 150000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 370.90 | loss: 0.9431 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 370.90 | loss: 0.9668 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 370.90 | loss: 1.1357 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 213
# |    time_elapsed     | 771
# |    total_timesteps  | 165000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 437.20 | loss: 1.3513 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 437.20 | loss: 1.2337 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 437.20 | loss: 1.3381 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 207
# |    time_elapsed     | 869
# |    total_timesteps  | 180000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 511.90 | loss: 1.2369 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 511.90 | loss: 2.4296 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 511.90 | loss: 1.9494 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 200
# |    time_elapsed     | 972
# |    total_timesteps  | 195000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 559.70 | loss: 1.5053 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 559.70 | loss: 1.5856 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 559.70 | loss: 1.2807 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 443
# |    time_elapsed     | 33
# |    total_timesteps  | 15000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 12.80 | loss: 0.0003 | eps: 0.325
# | adversary_1 -> mean_ep_rew | 12.80 | loss: 0.0006 | eps: 0.325
# | adversary_2 -> mean_ep_rew | 12.80 | loss: 0.0013 | eps: 0.325
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 328
# |    time_elapsed     | 91
# |    total_timesteps  | 30000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 8.40 | loss: 0.0759 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.40 | loss: 0.0746 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.40 | loss: 0.0018 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 295
# |    time_elapsed     | 152
# |    total_timesteps  | 45000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 6.70 | loss: 0.0515 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.70 | loss: 0.0037 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.70 | loss: 0.0049 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 278
# |    time_elapsed     | 215
# |    total_timesteps  | 60000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 14.60 | loss: 0.1073 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 14.60 | loss: 0.0055 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 14.60 | loss: 0.1400 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 267
# |    time_elapsed     | 280
# |    total_timesteps  | 75000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 21.60 | loss: 0.0961 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 21.60 | loss: 0.1259 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 21.60 | loss: 0.1668 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 257
# |    time_elapsed     | 349
# |    total_timesteps  | 90000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 87.40 | loss: 0.1419 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 87.40 | loss: 0.1323 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 87.40 | loss: 0.1659 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 248
# |    time_elapsed     | 423
# |    total_timesteps  | 105000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 202.20 | loss: 0.2696 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 202.20 | loss: 0.5172 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 202.20 | loss: 0.3031 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 238
# |    time_elapsed     | 503
# |    total_timesteps  | 120000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 240.60 | loss: 0.6080 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 240.60 | loss: 0.5015 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 240.60 | loss: 0.3956 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 229
# |    time_elapsed     | 588
# |    total_timesteps  | 135000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 329.90 | loss: 1.1802 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 329.90 | loss: 0.6346 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 329.90 | loss: 0.3779 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 221
# |    time_elapsed     | 678
# |    total_timesteps  | 150000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 362.00 | loss: 0.9717 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 362.00 | loss: 0.8127 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 362.00 | loss: 0.4536 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 213
# |    time_elapsed     | 772
# |    total_timesteps  | 165000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 425.20 | loss: 1.9146 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 425.20 | loss: 0.8536 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 425.20 | loss: 1.6657 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 206
# |    time_elapsed     | 871
# |    total_timesteps  | 180000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 504.40 | loss: 1.4945 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 504.40 | loss: 1.5901 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 504.40 | loss: 0.9618 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 199
# |    time_elapsed     | 975
# |    total_timesteps  | 195000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 518.30 | loss: 1.8710 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 518.30 | loss: 2.0433 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 518.30 | loss: 1.9165 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 435
# |    time_elapsed     | 34
# |    total_timesteps  | 15000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 14.70 | loss: 0.0745 | eps: 0.325
# | adversary_1 -> mean_ep_rew | 14.70 | loss: 0.2224 | eps: 0.325
# | adversary_2 -> mean_ep_rew | 14.70 | loss: 0.0747 | eps: 0.325
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 323
# |    time_elapsed     | 92
# |    total_timesteps  | 30000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 7.40 | loss: 0.1491 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.40 | loss: 0.1602 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.40 | loss: 0.0011 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 293
# |    time_elapsed     | 153
# |    total_timesteps  | 45000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 8.70 | loss: 0.0879 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.70 | loss: 0.0790 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.70 | loss: 0.0752 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 278
# |    time_elapsed     | 215
# |    total_timesteps  | 60000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 9.90 | loss: 0.0162 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 9.90 | loss: 0.1439 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 9.90 | loss: 0.0859 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 266
# |    time_elapsed     | 281
# |    total_timesteps  | 75000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 12.00 | loss: 0.0040 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 12.00 | loss: 0.0012 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 12.00 | loss: 0.0009 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 257
# |    time_elapsed     | 350
# |    total_timesteps  | 90000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 42.40 | loss: 0.4854 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 42.40 | loss: 0.2105 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 42.40 | loss: 0.0768 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 247
# |    time_elapsed     | 424
# |    total_timesteps  | 105000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 109.10 | loss: 0.3005 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 109.10 | loss: 0.1931 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 109.10 | loss: 0.1851 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 237
# |    time_elapsed     | 504
# |    total_timesteps  | 120000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 226.20 | loss: 1.0089 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 226.20 | loss: 0.2280 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 226.20 | loss: 0.3654 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 229
# |    time_elapsed     | 589
# |    total_timesteps  | 135000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 258.60 | loss: 0.4150 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 258.60 | loss: 0.5549 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 258.60 | loss: 0.9847 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 220
# |    time_elapsed     | 680
# |    total_timesteps  | 150000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 353.70 | loss: 0.7783 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 353.70 | loss: 0.3930 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 353.70 | loss: 1.1934 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 212
# |    time_elapsed     | 775
# |    total_timesteps  | 165000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 429.90 | loss: 1.0670 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 429.90 | loss: 0.9135 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 429.90 | loss: 0.8738 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 204
# |    time_elapsed     | 881
# |    total_timesteps  | 180000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 478.20 | loss: 1.5957 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 478.20 | loss: 1.1689 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 478.20 | loss: 1.7234 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 197
# |    time_elapsed     | 986
# |    total_timesteps  | 195000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 553.60 | loss: 1.4450 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 553.60 | loss: 1.7258 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 553.60 | loss: 2.1966 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 446
# |    time_elapsed     | 33
# |    total_timesteps  | 15000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 9.20 | loss: 0.0005 | eps: 0.325
# | adversary_1 -> mean_ep_rew | 9.20 | loss: 0.0748 | eps: 0.325
# | adversary_2 -> mean_ep_rew | 9.20 | loss: 0.0002 | eps: 0.325
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 327
# |    time_elapsed     | 91
# |    total_timesteps  | 30000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 7.60 | loss: 0.0028 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.60 | loss: 0.0006 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.60 | loss: 0.0010 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 294
# |    time_elapsed     | 152
# |    total_timesteps  | 45000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 5.40 | loss: 0.1470 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.40 | loss: 0.0030 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.40 | loss: 0.0580 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 278
# |    time_elapsed     | 215
# |    total_timesteps  | 60000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 11.90 | loss: 0.0834 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 11.90 | loss: 0.0823 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 11.90 | loss: 0.0745 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# ...
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 266
# |    time_elapsed     | 224
# |    total_timesteps  | 60000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 16.50 | loss: 0.1376 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 16.50 | loss: 0.0910 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 16.50 | loss: 0.0023 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 256
# |    time_elapsed     | 292
# |    total_timesteps  | 75000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 48.20 | loss: 0.1415 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 48.20 | loss: 0.1302 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 48.20 | loss: 0.0709 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 243
# |    time_elapsed     | 369
# |    total_timesteps  | 90000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 132.60 | loss: 0.2510 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 132.60 | loss: 0.3127 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 132.60 | loss: 0.1432 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 234
# |    time_elapsed     | 446
# |    total_timesteps  | 105000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 182.10 | loss: 0.3542 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 182.10 | loss: 0.5012 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 182.10 | loss: 0.2200 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 223
# |    time_elapsed     | 536
# |    total_timesteps  | 120000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 273.20 | loss: 0.7097 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 273.20 | loss: 0.7149 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 273.20 | loss: 0.5190 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 215
# |    time_elapsed     | 627
# |    total_timesteps  | 135000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 333.50 | loss: 1.1074 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 333.50 | loss: 0.5420 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 333.50 | loss: 0.7873 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 208
# |    time_elapsed     | 720
# |    total_timesteps  | 150000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 415.10 | loss: 1.2640 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 415.10 | loss: 0.8209 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 415.10 | loss: 1.7412 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 201
# |    time_elapsed     | 817
# |    total_timesteps  | 165000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 483.70 | loss: 1.2934 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 483.70 | loss: 1.2007 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 483.70 | loss: 1.3216 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 196
# |    time_elapsed     | 917
# |    total_timesteps  | 180000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 520.80 | loss: 2.0069 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 520.80 | loss: 1.4112 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 520.80 | loss: 1.3099 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 190
# |    time_elapsed     | 1022
# |    total_timesteps  | 195000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 593.30 | loss: 1.7233 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 593.30 | loss: 1.6337 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 593.30 | loss: 2.6332 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 434
# |    time_elapsed     | 34
# |    total_timesteps  | 15000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 8.80 | loss: 0.0751 | eps: 0.325
# | adversary_1 -> mean_ep_rew | 8.80 | loss: 0.1486 | eps: 0.325
# | adversary_2 -> mean_ep_rew | 8.80 | loss: 0.0003 | eps: 0.325
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 316
# |    time_elapsed     | 94
# |    total_timesteps  | 30000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 6.90 | loss: 0.0793 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.90 | loss: 0.0007 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.90 | loss: 0.1400 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 284
# |    time_elapsed     | 157
# |    total_timesteps  | 45000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 7.00 | loss: 0.0010 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.00 | loss: 0.0699 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.00 | loss: 0.0750 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 269
# |    time_elapsed     | 222
# |    total_timesteps  | 60000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 11.30 | loss: 0.0016 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 11.30 | loss: 0.0215 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 11.30 | loss: 0.0016 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 258
# |    time_elapsed     | 289
# |    total_timesteps  | 75000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 24.00 | loss: 0.1649 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 24.00 | loss: 0.0021 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 24.00 | loss: 0.0752 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 249
# |    time_elapsed     | 360
# |    total_timesteps  | 90000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 51.40 | loss: 0.0035 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 51.40 | loss: 0.1394 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 51.40 | loss: 0.1856 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 240
# |    time_elapsed     | 436
# |    total_timesteps  | 105000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 86.40 | loss: 0.1702 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 86.40 | loss: 0.2079 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 86.40 | loss: 0.1321 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 231
# |    time_elapsed     | 518
# |    total_timesteps  | 120000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 108.70 | loss: 0.2713 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 108.70 | loss: 0.0399 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 108.70 | loss: 0.1469 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 223
# |    time_elapsed     | 605
# |    total_timesteps  | 135000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 138.80 | loss: 0.3053 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 138.80 | loss: 0.5235 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 138.80 | loss: 0.4443 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 215
# |    time_elapsed     | 696
# |    total_timesteps  | 150000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 205.90 | loss: 0.2427 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 205.90 | loss: 0.1453 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 205.90 | loss: 0.4845 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 208
# |    time_elapsed     | 792
# |    total_timesteps  | 165000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 364.20 | loss: 0.7044 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 364.20 | loss: 0.8162 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 364.20 | loss: 1.3282 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 201
# |    time_elapsed     | 893
# |    total_timesteps  | 180000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 472.50 | loss: 0.8202 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 472.50 | loss: 1.3896 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 472.50 | loss: 0.9183 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 195
# |    time_elapsed     | 997
# |    total_timesteps  | 195000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 548.10 | loss: 1.2471 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 548.10 | loss: 1.2393 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 548.10 | loss: 2.1024 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 389
# |    time_elapsed     | 38
# |    total_timesteps  | 15000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 8.60 | loss: 0.0003 | eps: 0.325
# | adversary_1 -> mean_ep_rew | 8.60 | loss: 0.0004 | eps: 0.325
# | adversary_2 -> mean_ep_rew | 8.60 | loss: 0.0002 | eps: 0.325
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 286
# |    time_elapsed     | 104
# |    total_timesteps  | 30000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 4.60 | loss: 0.0014 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 4.60 | loss: 0.2230 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 4.60 | loss: 0.0012 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 269
# |    time_elapsed     | 166
# |    total_timesteps  | 45000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 5.30 | loss: 0.1523 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.30 | loss: 0.0005 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.30 | loss: 0.0478 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 260
# |    time_elapsed     | 230
# |    total_timesteps  | 60000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 8.30 | loss: 0.0009 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.30 | loss: 0.0020 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.30 | loss: 0.0068 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 252
# |    time_elapsed     | 297
# |    total_timesteps  | 75000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 9.10 | loss: 0.0004 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 9.10 | loss: 0.1502 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 9.10 | loss: 0.0005 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 244
# |    time_elapsed     | 367
# |    total_timesteps  | 90000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 21.00 | loss: 0.0728 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 21.00 | loss: 0.2993 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 21.00 | loss: 0.0747 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 237
# |    time_elapsed     | 443
# |    total_timesteps  | 105000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 25.00 | loss: 0.1392 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 25.00 | loss: 0.0848 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 25.00 | loss: 0.0987 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 228
# |    time_elapsed     | 524
# |    total_timesteps  | 120000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 78.80 | loss: 0.0833 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 78.80 | loss: 0.1558 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 78.80 | loss: 0.1655 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 221
# |    time_elapsed     | 610
# |    total_timesteps  | 135000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 117.40 | loss: 0.4458 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 117.40 | loss: 0.2522 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 117.40 | loss: 0.0653 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 213
# |    time_elapsed     | 701
# |    total_timesteps  | 150000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 146.40 | loss: 0.1667 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 146.40 | loss: 0.1163 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 146.40 | loss: 0.2854 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 207
# |    time_elapsed     | 796
# |    total_timesteps  | 165000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 194.30 | loss: 0.1254 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 194.30 | loss: 0.4899 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 194.30 | loss: 0.4812 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 200
# |    time_elapsed     | 896
# |    total_timesteps  | 180000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 292.10 | loss: 0.5159 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 292.10 | loss: 0.4683 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 292.10 | loss: 0.6877 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 194
# |    time_elapsed     | 1001
# |    total_timesteps  | 195000
# |    ep_len_mean      | 150
# | adversary_0 -> mean_ep_rew | 337.50 | loss: 1.0942 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 337.50 | loss: 0.8488 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 337.50 | loss: 0.7213 | eps: 0.100
# ----------------------------------
