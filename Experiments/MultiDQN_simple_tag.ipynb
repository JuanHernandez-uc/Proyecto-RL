# %%
import numpy as np
import random
import torch
import torch.nn as nn
from collections import deque
from mpe2 import simple_tag_v3
import supersuit as ss

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F
import random
from collections import deque
import numpy as np
import time

class MLP(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_dim=128):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, x):
        return self.net(x)


class ReplayBuffer:
    def __init__(self, size):
        self.buffer = deque(maxlen=size)

    def add(self, *transition):
        self.buffer.append(transition)

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        return (
            torch.as_tensor(np.stack(states), dtype=torch.float32),
            torch.as_tensor(actions, dtype=torch.long),
            torch.as_tensor(rewards, dtype=torch.float32),
            torch.as_tensor(np.stack(next_states), dtype=torch.float32),
            torch.as_tensor(dones, dtype=torch.float32)
        )

    def __len__(self):
        return len(self.buffer)


class DQN:
    def __init__(self,
            env,
            learning_rate = 1e-3,
            buffer_size = 300000,
            learning_starts = 100,
            batch_size = 32,
            tau = 1.0,
            gamma = 0.99,
            train_freq = 4,
            gradient_steps = 1,
            target_update_interval = 10000,
            exploration_fraction = 0.1,
            exploration_initial_eps = 1.0,
            exploration_final_eps = 0.05,
            max_grad_norm = 10,
            verbose = 0
        ):
        
        self.env = env
        self.device = torch.device("mps" if torch.mps.is_available() else "cpu")
        example_agent = env.agents[0]
        self.obs_dim = env.observation_space(example_agent).shape[0]
        self.n_actions = env.action_space(example_agent).n

        self.policy = MLP(self.obs_dim, self.n_actions).to(self.device)
        self.target_policy = MLP(self.obs_dim, self.n_actions).to(self.device)
        self.target_policy.load_state_dict(self.policy.state_dict())
        self.target_policy.eval()

        self.optimizer = optim.Adam(self.policy.parameters(), lr=learning_rate, betas=(0.9, 0.999))
        self.replay_buffer = ReplayBuffer(buffer_size)

        self.learning_starts = learning_starts
        self.batch_size = batch_size
        self.tau = tau
        self.gamma = gamma
        self.train_freq = train_freq
        self.gradient_steps = gradient_steps
        self.target_update_interval = target_update_interval
        self.exploration_initial_eps = exploration_initial_eps
        self.exploration_final_eps = exploration_final_eps
        self.exploration_fraction = exploration_fraction
        self.max_grad_norm = max_grad_norm
        self.verbose = verbose

        self.epsilon = self.exploration_initial_eps
        self.last_loss = None
        self.num_updates = 0


    def _select_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.n_actions)
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        with torch.no_grad():
            act_values = self.policy(state)
        return torch.argmax(act_values[0]).item()

    def _train_step(self):
        if len(self.replay_buffer) < self.batch_size:
            return

        self.policy.train()

        total_loss = 0
        for _ in range(self.gradient_steps):
            states, actions, rewards, next_states, dones = self.replay_buffer.sample(self.batch_size)
            states = states.to(self.device)
            actions = actions.to(self.device)
            rewards = rewards.to(self.device)
            next_states = next_states.to(self.device)
            dones = dones.to(self.device)

            q_values = self.policy(states).gather(1, actions.unsqueeze(1)).squeeze(1)

            with torch.no_grad():
                next_q_values = self.target_policy(next_states).max(1)[0]
                expected_q = rewards + self.gamma * next_q_values * (1 - dones)

            loss = F.smooth_l1_loss(q_values, expected_q)
            self.last_loss = loss.item()

            self.optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
            self.optimizer.step()

            self.num_updates += 1

            total_loss += loss.item()
        
        return total_loss / self.gradient_steps

    def learn(self, total_timesteps, log_interval=1000):
        obs, _ = self.env.reset()
        state = np.asarray(obs, dtype=np.float32)
        start_t  = time.perf_counter()
        ep_count = 0
        ep_lens  = deque(maxlen=100)
        ep_rews  = deque(maxlen=100)
        episode_reward = 0
        eps_decay_steps = int(self.exploration_fraction * total_timesteps)

        for t in range(1, total_timesteps + 1):
            self.total_timesteps = t
            self.epsilon = max(
                self.exploration_final_eps,
                self.exploration_initial_eps - (self.exploration_initial_eps - self.exploration_final_eps) * (t / eps_decay_steps)
            )

            action = self._select_action(state)
            next_state, reward, terminated, truncated, info = self.env.step(action)
            #reward = np.clip(reward, -1.0, 1.0)
            done = terminated or truncated
            next_state = np.asarray(next_state, dtype=np.float32)
            self.replay_buffer.add(state, action, reward, next_state, float(done))
            state = next_state
            episode_reward += reward

            if "episode" in info:
                ep_len = info["episode"]["l"]
                ep_rew = info["episode"]["r"]
                ep_lens.append(ep_len)
                ep_rews.append(ep_rew)
                ep_count += 1

            ## Fin del episodio
            if done:
                last_ep_reward = episode_reward
                obs, _ = self.env.reset()
                state = np.asarray(obs, dtype=np.float32)
                episode_reward = 0

            ## Cuándo se entrena la red
            if t > self.learning_starts and t % self.train_freq == 0:
                self._train_step()

            ## Sincronización de red target
            if self.num_updates > 0 and self.num_updates % self.target_update_interval == 0:
                self.target_policy.load_state_dict(self.policy.state_dict())
                self.target_policy.eval()

            if self.verbose and ep_count > 0 and ep_count % log_interval == 0 and done:
                fps = int(t / (time.perf_counter() - start_t))
                lr = self.optimizer.param_groups[0]["lr"]
                loss = self.last_loss if self.last_loss is not None else float("nan")
                print("----------------------------------")
                print(f"| rollout/            |          |")
                print(f"|    ep_len_mean      | {np.mean(ep_lens) if ep_lens else float('nan'):.0f}")
                print(f"|    ep_rew_mean      | {np.mean(ep_rews) if ep_rews else float('nan'):.0f}")
                print(f"|    exploration_rate | {self.epsilon:.3f}")
                print(f"| time/               |          |")
                print(f"|    episodes         | {ep_count}")
                print(f"|    fps              | {fps}")
                print(f"|    time_elapsed     | {int(time.perf_counter() - start_t)}")
                print(f"|    total_timesteps  | {t}")
                print(f"| train/              |          |")
                print(f"|    learning_rate    | {lr:.3g}")
                print(f"|    loss             | {loss:.4f}")
                print(f"|    n_updates        | {self.num_updates}")
                print("----------------------------------")

# %%
def learn_multiagent(env, agent_dict, total_timesteps, log_interval=1000):
    observations, _ = env.reset()
    episode_reward = {agent: 0 for agent in env.agents}
    ep_lens = deque(maxlen=100)
    ep_len = 0
    ep_rews = {agent: deque(maxlen=100) for agent in agent_dict}
    ep_count = 0
    t = 0
    start_t = time.perf_counter()

    eps_decay_steps = int(list(agent_dict.values())[0].exploration_fraction * total_timesteps)

    episode_rewards = []
    losses = []

    last_logged = -1

    while t < total_timesteps:
        actions = {}

        total_rewards = {agent: 0 for agent in env.agents}
        total_losses = {agent: 0 for agent in env.agents}

        for agent in env.agents:
            if agent in agent_dict:
                dqn = agent_dict[agent]
                dqn.epsilon = max(
                    dqn.exploration_final_eps,
                    dqn.exploration_initial_eps - (dqn.exploration_initial_eps - dqn.exploration_final_eps) * (t / eps_decay_steps)
                )
                action = dqn._select_action(observations[agent])
                actions[agent] = action
            else:
                actions[agent] = 0  # good agent se queda quieto

        next_obs, rewards, terminations, truncations, infos = env.step(actions)

        for agent in agent_dict:
            done = terminations[agent] or truncations[agent]
            dqn = agent_dict[agent]

            dqn.replay_buffer.add(
                np.array(observations[agent], dtype=np.float32),
                actions[agent],
                rewards[agent],
                np.array(next_obs[agent], dtype=np.float32),
                float(done)
            )
            episode_reward[agent] += rewards[agent]

            if t > dqn.learning_starts and t % dqn.train_freq == 0:
                loss = dqn._train_step()
                total_losses[agent] += loss if loss is not None else 0

            if dqn.num_updates > 0 and dqn.num_updates % dqn.target_update_interval == 0:
                dqn.target_policy.load_state_dict(dqn.policy.state_dict())
                dqn.target_policy.eval()

        losses.append(total_losses)

        t += 1
        observations = next_obs
        ep_len += 1
        # Fin de episodio
        if terminations["agent_0"] or truncations["agent_0"]:
            episode_rewards.append(episode_reward.copy())

            for agent in agent_dict:
                ep_rews[agent].append(episode_reward[agent])
                episode_reward[agent] = 0
            
            ep_lens.append(ep_len)  # si no tienes env.env_done_step puedes usar len(env.dones)
            ep_len = 0
            observations, _ = env.reset()
            ep_count += 1

        # Logging
        if ep_count > 0 and ep_count % log_interval == 0 and ep_count != last_logged:
            last_logged = ep_count
            fps = int(t / (time.perf_counter() - start_t))
            print("----------------------------------")
            print(f"| time/               |          |")
            print(f"|    episodes         | {ep_count}")
            print(f"|    fps              | {fps}")
            print(f"|    time_elapsed     | {int(time.perf_counter() - start_t)}")
            print(f"|    total_timesteps  | {t}")
            print(f"|    ep_len_mean      | {np.mean(ep_lens) if ep_lens else float('nan'):.0f}")
            for agent in agent_dict:
                dqn = agent_dict[agent]
                loss = dqn.last_loss if dqn.last_loss is not None else float("nan")
                print(f"| {agent} -> mean_ep_rew | {np.mean(ep_rews[agent]):.2f} | loss: {loss:.4f} | eps: {dqn.epsilon:.3f}")
            print("----------------------------------")

    return episode_rewards, losses

# %%
import matplotlib.pyplot as plt

def plot_total_rewards(rewards_dict_per_episode):
    """
    rewards_dict_per_episode: list de dicts por episodio, ej:
    [{agent_0: 10, agent_1: 12}, {agent_0: 5, agent_1: 7}, ...]
    """

    # llevar a cpu
    agent_names = rewards_dict_per_episode[0].keys()
    episode_count = len(rewards_dict_per_episode)

    for agent in agent_names:
        rewards = [episode[agent].cpu().item() if torch.is_tensor(episode[agent]) else episode[agent] for episode in rewards_dict_per_episode]
        plt.plot(rewards, label=agent)

    plt.xlabel("Episodio")
    plt.ylabel("Reward total por agente")
    plt.title("Recompensas por episodio")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Crear entorno paralelo
seed = 42
env = simple_tag_v3.parallel_env(render_mode='rgb_array', num_good=1, num_adversaries=1, num_obstacles=0, max_cycles=50, dynamic_rescaling = True)
env.reset(seed=seed)
agents = env.agents

dqn_params = {
    "learning_rate": 1e-3,
    "buffer_size": 5000,
    "learning_starts": 500,
    "batch_size": 128,
    "tau": 1.0,
    "gamma": 0.99,
    "train_freq": 1,
    "gradient_steps": 1,
    "target_update_interval": 500,
    "exploration_fraction": 0.1,
    "exploration_initial_eps": 1,
    "exploration_final_eps": 0.1,
    "max_grad_norm": 10,
    "verbose": 1,
}

# Inicializar agentes solo para los adversarios
agent_dict = {
    agent: DQN(env, **dqn_params)
    for agent in agents if agent.startswith("adversary")
}

# Entrenar los agentes adversarios
episode_rewards, episode_losses = learn_multiagent(env, agent_dict, total_timesteps=50000, log_interval=100)
# Out:
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 213
# |    time_elapsed     | 23
# |    total_timesteps  | 5000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 2.70 | loss: 0.0115 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 213
# |    time_elapsed     | 46
# |    total_timesteps  | 10000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 12.00 | loss: 0.5877 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 214
# |    time_elapsed     | 70
# |    total_timesteps  | 15000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 27.90 | loss: 0.9507 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 214
# |    time_elapsed     | 93
# |    total_timesteps  | 20000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 54.50 | loss: 0.9037 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 214
# |    time_elapsed     | 116
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 70.40 | loss: 3.1698 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 213
# |    time_elapsed     | 140
# |    total_timesteps  | 30000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 72.40 | loss: 4.1071 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 213
# |    time_elapsed     | 164
# |    total_timesteps  | 35000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 74.70 | loss: 2.8041 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 212
# |    time_elapsed     | 187
# |    total_timesteps  | 40000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 70.90 | loss: 1.8527 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 213
# |    time_elapsed     | 210
# |    total_timesteps  | 45000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 70.10 | loss: 1.7153 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 211
# |    time_elapsed     | 236
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 77.40 | loss: 3.1480 | eps: 0.100
# ----------------------------------

# %%
plot_total_rewards(episode_rewards)
plot_total_rewards(episode_losses)  # Graficar las pérdidas por episodio

# %%
def evaluate_agent_parallel(env, agent_dict, episodes=5):
    rewards = []

    for agent in agent_dict.values():
        agent.epsilon = 0  # Evaluación sin exploración

    for _ in range(episodes):
        observations, _ = env.reset()
        total_rewards = {agent: 0 for agent in env.agents}
        terminated = {agent: False for agent in env.agents}
        truncated = {agent: False for agent in env.agents}

        while not all(terminated[agent] or truncated[agent] for agent in env.agents):
            actions = {}
            for agent in env.agents:
                if terminated[agent] or truncated[agent]:
                    continue
                if agent in agent_dict:
                    actions[agent] = agent_dict[agent]._select_action(observations[agent])
                else:
                    actions[agent] = 0  # El agente bueno se queda quieto

            observations, rewards_step, terminated_step, truncated_step, _ = env.step(actions)

            for agent in env.agents:
                total_rewards[agent] += rewards_step[agent]
                terminated[agent] = terminated_step[agent]
                truncated[agent] = truncated_step[agent]

        rewards.append(total_rewards)

    return rewards

# %%
rewards_2 = evaluate_agent_parallel(env, agent_dict, episodes = 20)
plot_total_rewards(rewards_2)

# %%
import imageio
import numpy as np
from PIL import Image

def evaluate_multiagent_render_parallel(agent_dict, env, num_tests=1, save_path="multiagent_episode.mp4", fps=5, max_steps=500):
    all_frames = []

    # Política determinista: desactiva exploración
    for agent in agent_dict.values():
        agent.epsilon = 0.0

    for _ in range(num_tests):
        observations, _ = env.reset()
        terminated = {agent: False for agent in env.agents}
        truncated = {agent: False for agent in env.agents}
        frames = []
        step_count = 0

        while not all(terminated[agent] or truncated[agent] for agent in env.agents) and step_count < max_steps:
            actions = {}
            for agent in env.agents:
                if terminated[agent] or truncated[agent]:
                    continue
                if agent in agent_dict:
                    actions[agent] = agent_dict[agent]._select_action(observations[agent])
                else:
                    actions[agent] = 0  # agente bueno quieto

            observations, _, terminated_step, truncated_step, _ = env.step(actions)

            for agent in env.agents:
                terminated[agent] = terminated_step[agent]
                truncated[agent] = truncated_step[agent]

            frame = env.render()
            frame_resized = np.array(Image.fromarray(frame).resize((240, 240)))
            frames.append(frame_resized)
            step_count += 1

        all_frames.extend(frames + [frames[-1]] * 5)  # padding final

    imageio.mimsave(save_path, all_frames, fps=fps)
    print(f"Video guardado en: {save_path}")

# %%
evaluate_multiagent_render_parallel(agent_dict, env, num_tests=5, save_path="multiagent_episode.mp4", fps=5, max_steps=50)
# Out:
# Video guardado en: multiagent_episode.mp4

# %% [markdown]
# # 2 Agents

# %%
# Crear entorno paralelo
seed = 42
env = simple_tag_v3.parallel_env(render_mode='rgb_array', num_good=1, num_adversaries=2, num_obstacles=0, max_cycles=50, dynamic_rescaling = True)
env.reset(seed=seed)
agents = env.agents

dqn_params = {
    "learning_rate": 1e-3,
    "buffer_size": 10000,
    "learning_starts": 1000,
    "batch_size": 128,
    "tau": 1.0,
    "gamma": 0.99,
    "train_freq": 16,
    "gradient_steps": 4,
    "target_update_interval": 1000,
    "exploration_fraction": 0.1,
    "exploration_initial_eps": 1,
    "exploration_final_eps": 0.1,
    "max_grad_norm": 10,
    "verbose": 1,
}

# Inicializar agentes solo para los adversarios
agent_dict = {
    agent: DQN(env, **dqn_params)
    for agent in agents if agent.startswith("adversary")
}

# Entrenar los agentes adversarios
episode_rewards2, episode_losses2 = learn_multiagent(env, agent_dict, total_timesteps=100000, log_interval=100)
# Out:
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 484
# |    time_elapsed     | 10
# |    total_timesteps  | 5000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 3.20 | loss: 0.1274 | eps: 0.550
# | adversary_1 -> mean_ep_rew | 3.20 | loss: 0.2061 | eps: 0.550
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 412
# |    time_elapsed     | 24
# |    total_timesteps  | 10000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 2.50 | loss: 0.0095 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 2.50 | loss: 0.0053 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 380
# |    time_elapsed     | 39
# |    total_timesteps  | 15000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 2.90 | loss: 0.0778 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 2.90 | loss: 0.0030 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 368
# |    time_elapsed     | 54
# |    total_timesteps  | 20000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.60 | loss: 0.0811 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.60 | loss: 0.0150 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 359
# |    time_elapsed     | 69
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.20 | loss: 0.1460 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.20 | loss: 0.1575 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 354
# |    time_elapsed     | 84
# |    total_timesteps  | 30000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.20 | loss: 0.2210 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.20 | loss: 0.0078 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 350
# |    time_elapsed     | 99
# |    total_timesteps  | 35000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.00 | loss: 0.1121 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.00 | loss: 0.0251 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 347
# |    time_elapsed     | 115
# |    total_timesteps  | 40000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 11.50 | loss: 0.3164 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 11.50 | loss: 0.2126 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 346
# |    time_elapsed     | 129
# |    total_timesteps  | 45000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 22.60 | loss: 0.3304 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 22.60 | loss: 0.3104 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 345
# |    time_elapsed     | 144
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 51.10 | loss: 0.9906 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 51.10 | loss: 0.9026 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 343
# |    time_elapsed     | 160
# |    total_timesteps  | 55000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 55.80 | loss: 1.1150 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 55.80 | loss: 1.3887 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 342
# |    time_elapsed     | 175
# |    total_timesteps  | 60000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 83.90 | loss: 1.1789 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 83.90 | loss: 1.3605 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 341
# |    time_elapsed     | 190
# |    total_timesteps  | 65000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 90.20 | loss: 1.9556 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 90.20 | loss: 2.0812 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1400
# |    fps              | 340
# |    time_elapsed     | 205
# |    total_timesteps  | 70000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 94.00 | loss: 1.7233 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 94.00 | loss: 2.3666 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1500
# |    fps              | 339
# |    time_elapsed     | 221
# |    total_timesteps  | 75000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 103.90 | loss: 3.0805 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 103.90 | loss: 2.2232 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1600
# |    fps              | 337
# |    time_elapsed     | 237
# |    total_timesteps  | 80000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 108.80 | loss: 2.1917 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 108.80 | loss: 2.7065 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1700
# |    fps              | 337
# |    time_elapsed     | 252
# |    total_timesteps  | 85000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 101.20 | loss: 1.9726 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 101.20 | loss: 2.2989 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1800
# |    fps              | 336
# |    time_elapsed     | 267
# |    total_timesteps  | 90000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 113.90 | loss: 2.2449 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 113.90 | loss: 2.2193 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1900
# |    fps              | 336
# |    time_elapsed     | 282
# |    total_timesteps  | 95000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 124.10 | loss: 3.0843 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 124.10 | loss: 2.1034 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2000
# |    fps              | 335
# |    time_elapsed     | 298
# |    total_timesteps  | 100000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 118.40 | loss: 3.7083 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 118.40 | loss: 2.8594 | eps: 0.100
# ----------------------------------

# %%
plot_total_rewards(episode_rewards2)
plot_total_rewards(episode_losses2)  # Graficar las pérdidas por episodio

# %%
rewards_2 = evaluate_agent_parallel(env, agent_dict, episodes=20)
plot_total_rewards(rewards_2)

# %%
evaluate_multiagent_render_parallel(agent_dict, env, num_tests=5, save_path="multiagent_episode_2.mp4", fps=5, max_steps=50)
# Out:
# Video guardado en: multiagent_episode_2.mp4

# %% [markdown]
# # 3 Agents

# %%
# Crear entorno paralelo
seed = 42
env = simple_tag_v3.parallel_env(render_mode='rgb_array', num_good=1, num_adversaries=3, num_obstacles=0, max_cycles=50, dynamic_rescaling = True)
env.reset(seed=seed)
agents = env.agents

dqn_params = {
    "learning_rate": 1e-3,
    "buffer_size": 100000,
    "learning_starts": 1000,
    "batch_size": 128,
    "tau": 1.0,
    "gamma": 0.99,
    "train_freq": 16,
    "gradient_steps": 4,
    "target_update_interval": 1000,
    "exploration_fraction": 0.1,
    "exploration_initial_eps": 1,
    "exploration_final_eps": 0.1,
    "max_grad_norm": 10,
    "verbose": 1,
}

# Inicializar agentes solo para los adversarios
agent_dict = {
    agent: DQN(env, **dqn_params)
    for agent in agents if agent.startswith("adversary")
}

# Entrenar los agentes adversarios
episode_rewards3, episode_losses3 = learn_multiagent(env, agent_dict, total_timesteps=100000, log_interval=100)
# Out:
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 333
# |    time_elapsed     | 15
# |    total_timesteps  | 5000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.30 | loss: 0.1468 | eps: 0.550
# | adversary_1 -> mean_ep_rew | 7.30 | loss: 0.3546 | eps: 0.550
# | adversary_2 -> mean_ep_rew | 7.30 | loss: 0.2871 | eps: 0.550
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 276
# |    time_elapsed     | 36
# |    total_timesteps  | 10000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 4.00 | loss: 0.0669 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 4.00 | loss: 0.0763 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 4.00 | loss: 0.2087 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 254
# |    time_elapsed     | 59
# |    total_timesteps  | 15000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.60 | loss: 0.0218 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.60 | loss: 0.0904 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.60 | loss: 0.0063 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 248
# |    time_elapsed     | 80
# |    total_timesteps  | 20000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.40 | loss: 0.0876 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.40 | loss: 0.1488 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.40 | loss: 0.0948 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 245
# |    time_elapsed     | 102
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 11.90 | loss: 0.0914 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 11.90 | loss: 0.0836 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 11.90 | loss: 0.0258 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 243
# |    time_elapsed     | 123
# |    total_timesteps  | 30000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 15.60 | loss: 0.1600 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 15.60 | loss: 0.1673 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 15.60 | loss: 0.1977 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 240
# |    time_elapsed     | 145
# |    total_timesteps  | 35000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 17.90 | loss: 0.1151 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 17.90 | loss: 0.5645 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 17.90 | loss: 0.2413 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 239
# |    time_elapsed     | 167
# |    total_timesteps  | 40000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 16.60 | loss: 0.1592 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 16.60 | loss: 0.4465 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 16.60 | loss: 0.6268 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 237
# |    time_elapsed     | 189
# |    total_timesteps  | 45000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 22.40 | loss: 0.8455 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 22.40 | loss: 0.5357 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 22.40 | loss: 0.3092 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 233
# |    time_elapsed     | 213
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 29.70 | loss: 0.3817 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 29.70 | loss: 0.2874 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 29.70 | loss: 0.5510 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 232
# |    time_elapsed     | 236
# |    total_timesteps  | 55000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 31.50 | loss: 0.8757 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 31.50 | loss: 0.2416 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 31.50 | loss: 0.3625 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 232
# |    time_elapsed     | 257
# |    total_timesteps  | 60000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 24.30 | loss: 0.6852 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 24.30 | loss: 2.0163 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 24.30 | loss: 0.3167 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 232
# |    time_elapsed     | 279
# |    total_timesteps  | 65000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 25.40 | loss: 0.5463 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 25.40 | loss: 1.1223 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 25.40 | loss: 0.3343 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1400
# |    fps              | 231
# |    time_elapsed     | 301
# |    total_timesteps  | 70000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 27.80 | loss: 0.6598 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 27.80 | loss: 0.4453 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 27.80 | loss: 1.5180 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1500
# |    fps              | 231
# |    time_elapsed     | 324
# |    total_timesteps  | 75000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 27.40 | loss: 1.2216 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 27.40 | loss: 0.8196 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 27.40 | loss: 0.4522 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1600
# |    fps              | 230
# |    time_elapsed     | 346
# |    total_timesteps  | 80000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 29.60 | loss: 1.4809 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 29.60 | loss: 1.0105 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 29.60 | loss: 1.5251 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1700
# |    fps              | 228
# |    time_elapsed     | 371
# |    total_timesteps  | 85000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 30.10 | loss: 1.6855 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 30.10 | loss: 0.8760 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 30.10 | loss: 1.6810 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1800
# |    fps              | 228
# |    time_elapsed     | 394
# |    total_timesteps  | 90000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 36.90 | loss: 1.4870 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 36.90 | loss: 2.2052 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 36.90 | loss: 1.1259 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1900
# |    fps              | 228
# |    time_elapsed     | 416
# |    total_timesteps  | 95000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 33.60 | loss: 0.7419 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 33.60 | loss: 2.1785 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 33.60 | loss: 1.2809 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2000
# |    fps              | 227
# |    time_elapsed     | 439
# |    total_timesteps  | 100000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 30.30 | loss: 2.4664 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 30.30 | loss: 0.9984 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 30.30 | loss: 1.8542 | eps: 0.100
# ----------------------------------

# %%
plot_total_rewards(episode_rewards3)
plot_total_rewards(episode_losses3)  # Graficar las pérdidas por episodio

# %%
rewards_3 = evaluate_agent_parallel(env, agent_dict, episodes=20)
plot_total_rewards(rewards_3)

# %%
evaluate_multiagent_render_parallel(agent_dict, env, num_tests=5, save_path="multiagent_episode_3.mp4", fps=5, max_steps=50)
# Out:
# Video guardado en: multiagent_episode_3.mp4

# %% [markdown]
# ## 3 agents and obstacle

# %%
# Crear entorno paralelo
seed = 42
env = simple_tag_v3.parallel_env(render_mode='rgb_array', num_good=1, num_adversaries=3, num_obstacles=1, max_cycles=50, dynamic_rescaling = True)
env.reset(seed=seed)
agents = env.agents

dqn_params = {
    "learning_rate": 1e-4,
    "buffer_size": 1000000,
    "learning_starts": 5000,
    "batch_size": 128,
    "tau": 1.0,
    "gamma": 0.99,
    "train_freq": 16,
    "gradient_steps": 4,
    "target_update_interval": 2000,
    "exploration_fraction": 0.1,
    "exploration_initial_eps": 1,
    "exploration_final_eps": 0.1,
    "max_grad_norm": 10,
    "verbose": 1,
}

# Inicializar agentes solo para los adversarios
agent_dict = {
    agent: DQN(env, **dqn_params)
    for agent in agents if agent.startswith("adversary")
}

# Entrenar los agentes adversarios
episode_rewards4, episode_losses4 = learn_multiagent(env, agent_dict, total_timesteps=150000, log_interval=100)
# Out:
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 2304
# |    time_elapsed     | 2
# |    total_timesteps  | 5000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.60 | loss: nan | eps: 0.700
# | adversary_1 -> mean_ep_rew | 5.60 | loss: nan | eps: 0.700
# | adversary_2 -> mean_ep_rew | 5.60 | loss: nan | eps: 0.700
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 469
# |    time_elapsed     | 21
# |    total_timesteps  | 10000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.10 | loss: 0.0006 | eps: 0.400
# | adversary_1 -> mean_ep_rew | 8.10 | loss: 0.1475 | eps: 0.400
# | adversary_2 -> mean_ep_rew | 8.10 | loss: 0.0745 | eps: 0.400
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 358
# |    time_elapsed     | 41
# |    total_timesteps  | 15000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 4.30 | loss: 0.0748 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 4.30 | loss: 0.2222 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 4.30 | loss: 0.0752 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 314
# |    time_elapsed     | 63
# |    total_timesteps  | 20000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.40 | loss: 0.0753 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.40 | loss: 0.0748 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.40 | loss: 0.0011 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 292
# |    time_elapsed     | 85
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.40 | loss: 0.0745 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.40 | loss: 0.0754 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.40 | loss: 0.0748 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 278
# |    time_elapsed     | 107
# |    total_timesteps  | 30000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 4.10 | loss: 0.0015 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 4.10 | loss: 0.0741 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 4.10 | loss: 0.0746 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 270
# |    time_elapsed     | 129
# |    total_timesteps  | 35000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.60 | loss: 0.1481 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.60 | loss: 0.0006 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.60 | loss: 0.0756 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 263
# |    time_elapsed     | 151
# |    total_timesteps  | 40000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.50 | loss: 0.0014 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.50 | loss: 0.1483 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.50 | loss: 0.0010 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 258
# |    time_elapsed     | 174
# |    total_timesteps  | 45000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.10 | loss: 0.0751 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.10 | loss: 0.0006 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.10 | loss: 0.0745 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 255
# |    time_elapsed     | 195
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.70 | loss: 0.0004 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.70 | loss: 0.2222 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.70 | loss: 0.0008 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 252
# |    time_elapsed     | 217
# |    total_timesteps  | 55000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.20 | loss: 0.0746 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.20 | loss: 0.2229 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.20 | loss: 0.2232 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 250
# |    time_elapsed     | 239
# |    total_timesteps  | 60000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.80 | loss: 0.0750 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.80 | loss: 0.0750 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.80 | loss: 0.0747 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 248
# |    time_elapsed     | 261
# |    total_timesteps  | 65000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.30 | loss: 0.1484 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.30 | loss: 0.0758 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.30 | loss: 0.0024 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1400
# |    fps              | 246
# |    time_elapsed     | 283
# |    total_timesteps  | 70000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 4.20 | loss: 0.2984 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 4.20 | loss: 0.2963 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 4.20 | loss: 0.2229 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1500
# |    fps              | 245
# |    time_elapsed     | 305
# |    total_timesteps  | 75000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.00 | loss: 0.0014 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.00 | loss: 0.0012 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.00 | loss: 0.0011 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1600
# |    fps              | 243
# |    time_elapsed     | 327
# |    total_timesteps  | 80000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.60 | loss: 0.1502 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.60 | loss: 0.2958 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.60 | loss: 0.0745 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1700
# |    fps              | 242
# |    time_elapsed     | 350
# |    total_timesteps  | 85000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.00 | loss: 0.0748 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.00 | loss: 0.1521 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.00 | loss: 0.0747 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1800
# |    fps              | 241
# |    time_elapsed     | 372
# |    total_timesteps  | 90000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.30 | loss: 0.2228 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.30 | loss: 0.2241 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.30 | loss: 0.0036 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1900
# |    fps              | 241
# |    time_elapsed     | 393
# |    total_timesteps  | 95000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.00 | loss: 0.1496 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.00 | loss: 0.2215 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.00 | loss: 0.0012 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2000
# |    fps              | 240
# |    time_elapsed     | 415
# |    total_timesteps  | 100000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.60 | loss: 0.0757 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.60 | loss: 0.2216 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.60 | loss: 0.0759 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2100
# |    fps              | 240
# |    time_elapsed     | 436
# |    total_timesteps  | 105000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.20 | loss: 0.0021 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.20 | loss: 0.0719 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.20 | loss: 0.1499 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2200
# |    fps              | 239
# |    time_elapsed     | 459
# |    total_timesteps  | 110000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 11.70 | loss: 0.2230 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 11.70 | loss: 0.2236 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 11.70 | loss: 0.1484 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2300
# |    fps              | 238
# |    time_elapsed     | 482
# |    total_timesteps  | 115000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.80 | loss: 0.0752 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.80 | loss: 0.0022 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.80 | loss: 0.1491 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2400
# |    fps              | 237
# |    time_elapsed     | 505
# |    total_timesteps  | 120000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.30 | loss: 0.2987 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.30 | loss: 0.2998 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.30 | loss: 0.0764 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2500
# |    fps              | 235
# |    time_elapsed     | 529
# |    total_timesteps  | 125000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 11.30 | loss: 0.3663 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 11.30 | loss: 0.2988 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 11.30 | loss: 0.0747 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2600
# |    fps              | 235
# |    time_elapsed     | 552
# |    total_timesteps  | 130000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.00 | loss: 0.1469 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.00 | loss: 0.2227 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.00 | loss: 0.1479 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2700
# |    fps              | 234
# |    time_elapsed     | 576
# |    total_timesteps  | 135000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 9.70 | loss: 0.0012 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 9.70 | loss: 0.1524 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 9.70 | loss: 0.0764 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2800
# |    fps              | 233
# |    time_elapsed     | 599
# |    total_timesteps  | 140000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 9.70 | loss: 0.1486 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 9.70 | loss: 0.2213 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 9.70 | loss: 0.1528 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2900
# |    fps              | 232
# |    time_elapsed     | 622
# |    total_timesteps  | 145000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 11.30 | loss: 0.0888 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 11.30 | loss: 0.2971 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 11.30 | loss: 0.0743 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3000
# |    fps              | 232
# |    time_elapsed     | 645
# |    total_timesteps  | 150000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 10.50 | loss: 0.0073 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 10.50 | loss: 0.0771 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 10.50 | loss: 0.3029 | eps: 0.100
# ----------------------------------

# %%
plot_total_rewards(episode_rewards4)
plot_total_rewards(episode_losses4)  # Graficar las pérdidas por episodio
rewards_4 = evaluate_agent_parallel(env, agent_dict, episodes=20)
plot_total_rewards(rewards_4)

# %%
evaluate_multiagent_render_parallel(agent_dict, env, num_tests=5, save_path="multiagent_episode_3_obstacles.mp4", fps=5, max_steps=50)
# Out:
# Video guardado en: multiagent_episode_3_obstacles.mp4

# %% [markdown]
# ## Best params

# %%
from itertools import product
import copy

dqn_params = {
    "learning_rate": [0.001],
    "buffer_size": [50000],
    "learning_starts": [5000],
    "batch_size": [64, 128],
    "tau": [1.0],
    "gamma": [0.99],
    "train_freq": [1, 4, 16],
    "gradient_steps": [1, 4, 8],
    "target_update_interval": [100, 500, 1000],
    "exploration_fraction": [0.1],
    "exploration_initial_eps": [0.1],
    "exploration_final_eps": [0.1],
    "max_grad_norm": [10],
    "verbose": [1]
}

# %%
keys, values = zip(*dqn_params.items())
combinations = list(product(*values))

# %%
len(combinations)
# Out:
# 54

# %%
best_params = None
best_score = float('-inf')

for i, combo in enumerate(combinations):
    params = dict(zip(keys, combo))

    print(f"Combinación {i+1}:")
    for k, v in params.items():
        print(f"  {k}: {v}")

    env = simple_tag_v3.parallel_env(num_good=1, num_adversaries=3, num_obstacles=2, max_cycles=50)
    env.reset(seed=seed)
    agents = env.agents

    agent_dict = {
        agent: DQN(env, **params)
        for agent in agents if agent.startswith("adversary")
    }

    episode_rewards, episode_losses = learn_multiagent(env, agent_dict, total_timesteps=50000, log_interval=500)
    mean_reward = np.mean([np.mean(list(reward.values())) for reward in episode_rewards])
    
    print(f"Mean reward: {mean_reward}")
    score = mean_reward
    if score > best_score:
        best_score = score
        best_params = copy.deepcopy(params)
# Out:
# Combinación 1:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 1
#   target_update_interval: 100
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 86
# |    time_elapsed     | 287
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.70 | loss: 5.6416 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.70 | loss: 4.9953 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.70 | loss: 4.9069 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 80
# |    time_elapsed     | 622
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.90 | loss: 83.2367 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.90 | loss: 39.3256 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.90 | loss: 49.0231 | eps: 0.100
# ----------------------------------
# Mean reward: 4.74
# Combinación 2:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 1
#   target_update_interval: 500
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 92
# |    time_elapsed     | 270
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 14.40 | loss: 0.3439 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 14.40 | loss: 0.5150 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 14.40 | loss: 1.1506 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 84
# |    time_elapsed     | 590
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.50 | loss: 2.4723 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.50 | loss: 0.8830 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.50 | loss: 1.0238 | eps: 0.100
# ----------------------------------
# Mean reward: 6.57
# Combinación 3:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 1
#   target_update_interval: 1000
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 96
# |    time_elapsed     | 258
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 14.80 | loss: 0.0368 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 14.80 | loss: 0.1864 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 14.80 | loss: 0.2030 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 86
# |    time_elapsed     | 575
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 10.20 | loss: 0.4240 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 10.20 | loss: 0.9844 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 10.20 | loss: 1.0606 | eps: 0.100
# ----------------------------------
# Mean reward: 6.3975
# Combinación 4:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 4
#   target_update_interval: 100
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 27
# |    time_elapsed     | 913
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.50 | loss: 2109.7776 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.50 | loss: 3178.4866 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.50 | loss: 39133.5000 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 24
# |    time_elapsed     | 2054
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 2.60 | loss: 557265536.0000 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 2.60 | loss: 322776352.0000 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 2.60 | loss: 1366986496.0000 | eps: 0.100
# ----------------------------------
# Mean reward: 3.45
# Combinación 5:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 4
#   target_update_interval: 500
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 27
# |    time_elapsed     | 913
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.70 | loss: 6.3301 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.70 | loss: 3.8510 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.70 | loss: 9.5935 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 24
# |    time_elapsed     | 2056
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 3.90 | loss: 84.0825 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 3.90 | loss: 79.1158 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 3.90 | loss: 54.4736 | eps: 0.100
# ----------------------------------
# Mean reward: 4.305
# Combinación 6:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 4
#   target_update_interval: 1000
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 27
# |    time_elapsed     | 923
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.30 | loss: 1.9654 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.30 | loss: 3.2911 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.30 | loss: 4.2038 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 24
# |    time_elapsed     | 2070
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.90 | loss: 9.6278 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.90 | loss: 7.9350 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.90 | loss: 16.0330 | eps: 0.100
# ----------------------------------
# Mean reward: 6.18
# Combinación 7:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 8
#   target_update_interval: 100
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 13
# |    time_elapsed     | 1802
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.00 | loss: 120365.1406 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.00 | loss: 11080.9824 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.00 | loss: 25798.1602 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 12
# |    time_elapsed     | 4058
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.20 | loss: 9743698944.0000 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.20 | loss: 3580308992.0000 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.20 | loss: 14141755392.0000 | eps: 0.100
# ----------------------------------
# Mean reward: 3.78
# Combinación 8:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 8
#   target_update_interval: 500
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 13
# |    time_elapsed     | 1793
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.50 | loss: 8.2351 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.50 | loss: 14.5763 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.50 | loss: 8.9755 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 12
# |    time_elapsed     | 4045
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 9.30 | loss: 325.8270 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 9.30 | loss: 283.0399 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 9.30 | loss: 243.4678 | eps: 0.100
# ----------------------------------
# Mean reward: 5.715
# Combinación 9:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 8
#   target_update_interval: 1000
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 13
# |    time_elapsed     | 1802
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.00 | loss: 12.4479 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.00 | loss: 6.0850 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.00 | loss: 11.0643 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 12
# |    time_elapsed     | 4067
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.40 | loss: 469.9876 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.40 | loss: 268.8475 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.40 | loss: 475.8857 | eps: 0.100
# ----------------------------------
# Mean reward: 4.56
# Combinación 10:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 4
#   gradient_steps: 1
#   target_update_interval: 100
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 260
# |    time_elapsed     | 96
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 10.00 | loss: 0.2311 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 10.00 | loss: 0.1623 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 10.00 | loss: 0.1707 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 240
# |    time_elapsed     | 207
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 13.90 | loss: 0.0363 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 13.90 | loss: 0.3564 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 13.90 | loss: 0.1722 | eps: 0.100
# ----------------------------------
# Mean reward: 5.7825
# Combinación 11:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 4
#   gradient_steps: 1
#   target_update_interval: 500
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 258
# |    time_elapsed     | 96
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.90 | loss: 0.0068 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.90 | loss: 0.0023 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.90 | loss: 0.1552 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 239
# |    time_elapsed     | 208
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 9.70 | loss: 0.0474 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 9.70 | loss: 0.4970 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 9.70 | loss: 0.0975 | eps: 0.100
# ----------------------------------
# Mean reward: 5.07
# Combinación 12:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 4
#   gradient_steps: 1
#   target_update_interval: 1000
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 258
# |    time_elapsed     | 96
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.80 | loss: 0.1643 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.80 | loss: 0.3113 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.80 | loss: 0.1411 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 237
# |    time_elapsed     | 210
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 10.80 | loss: 0.1505 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 10.80 | loss: 0.3320 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 10.80 | loss: 0.1494 | eps: 0.100
# ----------------------------------
# Mean reward: 4.8225
# Combinación 13:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 4
#   gradient_steps: 4
#   target_update_interval: 100
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 94
# |    time_elapsed     | 264
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.30 | loss: 4.3580 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.30 | loss: 0.6467 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.30 | loss: 2.0747 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 85
# |    time_elapsed     | 584
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.90 | loss: 334.1084 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.90 | loss: 6.2757 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.90 | loss: 21.5815 | eps: 0.100
# ----------------------------------
# Mean reward: 4.23
# Combinación 14:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 4
#   gradient_steps: 4
#   target_update_interval: 500
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 94
# |    time_elapsed     | 264
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 14.30 | loss: 0.4967 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 14.30 | loss: 0.3369 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 14.30 | loss: 0.4648 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 85
# |    time_elapsed     | 582
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 12.20 | loss: 1.4911 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 12.20 | loss: 1.2133 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 12.20 | loss: 1.1460 | eps: 0.100
# ----------------------------------
# Mean reward: 6.2175
# Combinación 15:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 4
#   gradient_steps: 4
#   target_update_interval: 1000
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 93
# |    time_elapsed     | 267
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 11.00 | loss: 0.2842 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 11.00 | loss: 0.3452 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 11.00 | loss: 0.3145 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 85
# |    time_elapsed     | 585
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 11.70 | loss: 1.1212 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 11.70 | loss: 0.6707 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 11.70 | loss: 0.7272 | eps: 0.100
# ----------------------------------
# Mean reward: 6.8175
# Combinación 16:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 4
#   gradient_steps: 8
#   target_update_interval: 100
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 51
# |    time_elapsed     | 488
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.00 | loss: 5.0863 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.00 | loss: 2.9750 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.00 | loss: 3.9332 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 46
# |    time_elapsed     | 1082
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.50 | loss: 125.6713 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.50 | loss: 142.4095 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.50 | loss: 103.6308 | eps: 0.100
# ----------------------------------
# Mean reward: 5.205
# Combinación 17:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 4
#   gradient_steps: 8
#   target_update_interval: 500
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 51
# |    time_elapsed     | 485
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 14.30 | loss: 1.1294 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 14.30 | loss: 1.5434 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 14.30 | loss: 0.7468 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 46
# |    time_elapsed     | 1079
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.00 | loss: 2.9625 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.00 | loss: 3.1079 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.00 | loss: 2.9236 | eps: 0.100
# ----------------------------------
# Mean reward: 6.8775
# Combinación 18:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 4
#   gradient_steps: 8
#   target_update_interval: 1000
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 52
# |    time_elapsed     | 480
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 13.60 | loss: 0.4765 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 13.60 | loss: 0.6328 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 13.60 | loss: 0.7443 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 46
# |    time_elapsed     | 1064
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 10.40 | loss: 4.2836 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 10.40 | loss: 4.0742 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 10.40 | loss: 3.0996 | eps: 0.100
# ----------------------------------
# Mean reward: 7.005
# Combinación 19:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 16
#   gradient_steps: 1
#   target_update_interval: 100
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 494
# |    time_elapsed     | 50
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.60 | loss: 0.0031 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.60 | loss: 0.1507 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.60 | loss: 0.0040 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 469
# |    time_elapsed     | 106
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.50 | loss: 0.1543 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.50 | loss: 0.2998 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.50 | loss: 0.0116 | eps: 0.100
# ----------------------------------
# Mean reward: 3.7275
# Combinación 20:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 16
#   gradient_steps: 1
#   target_update_interval: 500
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 490
# |    time_elapsed     | 51
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.00 | loss: 0.1478 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.00 | loss: 0.1485 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.00 | loss: 0.1479 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 466
# |    time_elapsed     | 107
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.20 | loss: 0.1488 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.20 | loss: 0.1482 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.20 | loss: 0.7375 | eps: 0.100
# ----------------------------------
# Mean reward: 4.02
# Combinación 21:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 16
#   gradient_steps: 1
#   target_update_interval: 1000
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 492
# |    time_elapsed     | 50
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.90 | loss: 0.0023 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.90 | loss: 0.0017 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.90 | loss: 0.0012 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 468
# |    time_elapsed     | 106
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.60 | loss: 0.1511 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.60 | loss: 0.1492 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.60 | loss: 0.1501 | eps: 0.100
# ----------------------------------
# Mean reward: 4.02
# Combinación 22:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 16
#   gradient_steps: 4
#   target_update_interval: 100
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 260
# |    time_elapsed     | 96
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 13.50 | loss: 0.0158 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 13.50 | loss: 0.1443 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 13.50 | loss: 0.0111 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 241
# |    time_elapsed     | 207
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 12.10 | loss: 0.1255 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 12.10 | loss: 0.2917 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 12.10 | loss: 0.0657 | eps: 0.100
# ----------------------------------
# Mean reward: 7.635
# Combinación 23:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 16
#   gradient_steps: 4
#   target_update_interval: 500
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 260
# |    time_elapsed     | 96
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.30 | loss: 0.0063 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.30 | loss: 0.0043 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.30 | loss: 0.3694 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 241
# |    time_elapsed     | 207
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 12.10 | loss: 0.1579 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 12.10 | loss: 0.0749 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 12.10 | loss: 0.0497 | eps: 0.100
# ----------------------------------
# Mean reward: 5.0025
# Combinación 24:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 16
#   gradient_steps: 4
#   target_update_interval: 1000
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 261
# |    time_elapsed     | 95
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.40 | loss: 0.1721 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.40 | loss: 0.1509 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.40 | loss: 0.0029 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 243
# |    time_elapsed     | 205
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.20 | loss: 0.0148 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.20 | loss: 0.0306 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.20 | loss: 0.0126 | eps: 0.100
# ----------------------------------
# Mean reward: 4.275
# Combinación 25:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 16
#   gradient_steps: 8
#   target_update_interval: 100
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 164
# |    time_elapsed     | 152
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 12.20 | loss: 0.2741 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 12.20 | loss: 0.3887 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 12.20 | loss: 0.1599 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 148
# |    time_elapsed     | 337
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 10.60 | loss: 3.0374 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 10.60 | loss: 0.4792 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 10.60 | loss: 1.1155 | eps: 0.100
# ----------------------------------
# Mean reward: 6.78
# Combinación 26:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 16
#   gradient_steps: 8
#   target_update_interval: 500
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 164
# |    time_elapsed     | 152
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.50 | loss: 0.0277 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.50 | loss: 0.1714 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.50 | loss: 0.0063 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 152
# |    time_elapsed     | 328
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 9.30 | loss: 0.2607 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 9.30 | loss: 0.1334 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 9.30 | loss: 0.4291 | eps: 0.100
# ----------------------------------
# Mean reward: 5.295
# Combinación 27:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 64
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 16
#   gradient_steps: 8
#   target_update_interval: 1000
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 164
# |    time_elapsed     | 152
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 10.10 | loss: 0.0056 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 10.10 | loss: 0.2130 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 10.10 | loss: 0.1326 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 152
# |    time_elapsed     | 327
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 20.80 | loss: 0.4341 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 20.80 | loss: 0.3309 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 20.80 | loss: 0.5095 | eps: 0.100
# ----------------------------------
# Mean reward: 7.53
# Combinación 28:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 128
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 1
#   target_update_interval: 100
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 92
# |    time_elapsed     | 270
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 9.80 | loss: 4.0936 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 9.80 | loss: 5.1332 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 9.80 | loss: 3.1168 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 82
# |    time_elapsed     | 604
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.00 | loss: 97.7104 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.00 | loss: 166.1442 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.00 | loss: 41.9656 | eps: 0.100
# ----------------------------------
# Mean reward: 5.3025
# Combinación 29:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 128
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 1
#   target_update_interval: 500
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 91
# |    time_elapsed     | 274
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 12.20 | loss: 0.2440 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 12.20 | loss: 0.9447 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 12.20 | loss: 0.5887 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 82
# |    time_elapsed     | 606
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.70 | loss: 0.6900 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.70 | loss: 4.0957 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.70 | loss: 2.8607 | eps: 0.100
# ----------------------------------
# Mean reward: 5.34
# Combinación 30:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 128
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 1
#   target_update_interval: 1000
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 90
# |    time_elapsed     | 275
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 13.40 | loss: 0.3019 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 13.40 | loss: 0.7472 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 13.40 | loss: 0.4747 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 82
# |    time_elapsed     | 608
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 10.40 | loss: 1.0766 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 10.40 | loss: 1.3395 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 10.40 | loss: 1.9916 | eps: 0.100
# ----------------------------------
# Mean reward: 7.71
# Combinación 31:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 128
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 4
#   target_update_interval: 100
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 25
# |    time_elapsed     | 989
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.90 | loss: 80575.0391 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.90 | loss: 7106.0498 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.90 | loss: 17220.6348 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 22
# |    time_elapsed     | 2209
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 3.70 | loss: 3535976448.0000 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 3.70 | loss: 2706787328.0000 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 3.70 | loss: 2965785600.0000 | eps: 0.100
# ----------------------------------
# Mean reward: 3.9675
# Combinación 32:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 128
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 4
#   target_update_interval: 500
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 25
# |    time_elapsed     | 973
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 8.90 | loss: 8.9540 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 8.90 | loss: 58.4101 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 8.90 | loss: 22.5441 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 22
# |    time_elapsed     | 2204
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.00 | loss: 127.8041 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.00 | loss: 767.0588 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.00 | loss: 132.2225 | eps: 0.100
# ----------------------------------
# Mean reward: 4.7325
# Combinación 33:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 128
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 4
#   target_update_interval: 1000
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 25
# |    time_elapsed     | 978
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 9.80 | loss: 3.7392 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 9.80 | loss: 5.2300 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 9.80 | loss: 5.2750 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 22
# |    time_elapsed     | 2210
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 9.90 | loss: 15.0055 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 9.90 | loss: 39.0359 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 9.90 | loss: 15.4415 | eps: 0.100
# ----------------------------------
# Mean reward: 5.85
# Combinación 34:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 128
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 8
#   target_update_interval: 100
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 12
# |    time_elapsed     | 1946
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.70 | loss: 21930.9844 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.70 | loss: 178512.0156 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.70 | loss: 22083.2500 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 11
# |    time_elapsed     | 4488
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 3.60 | loss: 2785905920.0000 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 3.60 | loss: 7472071680.0000 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 3.60 | loss: 1885036416.0000 | eps: 0.100
# ----------------------------------
# Mean reward: 3.7575
# Combinación 35:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 128
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 8
#   target_update_interval: 500
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 12
# |    time_elapsed     | 2069
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 7.00 | loss: 23.9127 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 7.00 | loss: 34.3191 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 7.00 | loss: 45.2896 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 10
# |    time_elapsed     | 4641
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 3.80 | loss: 318.7347 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 3.80 | loss: 375.7349 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 3.80 | loss: 915.8251 | eps: 0.100
# ----------------------------------
# Mean reward: 4.4625
# Combinación 36:
#   learning_rate: 0.001
#   buffer_size: 50000
#   learning_starts: 5000
#   batch_size: 128
#   tau: 1.0
#   gamma: 0.99
#   train_freq: 1
#   gradient_steps: 8
#   target_update_interval: 1000
#   exploration_fraction: 0.1
#   exploration_initial_eps: 0.1
#   exploration_final_eps: 0.1
#   max_grad_norm: 10
#   verbose: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 20
#      13 agents = env.agents
#      15 agent_dict = {
#      16     agent: DQN(env, **params)
#      17     for agent in agents if agent.startswith("adversary")
#      18 }
# ---> 20 episode_rewards, episode_losses = learn_multiagent(env, agent_dict, total_timesteps=50000, log_interval=500)
#      21 mean_reward = np.mean([np.mean(list(reward.values())) for reward in episode_rewards])
#      23 print(f"Mean reward: {mean_reward}")
#
# Cell In[3], line 52, in learn_multiagent(env, agent_dict, total_timesteps, log_interval)
#      49 episode_reward[agent] += rewards[agent]
#      51 if t > dqn.learning_starts and t % dqn.train_freq == 0:
# ---> 52     loss = dqn._train_step()
#      53     total_losses[agent] += loss if loss is not None else 0
#      55 if dqn.num_updates > 0 and dqn.num_updates % dqn.target_update_interval == 0:
#
# Cell In[2], line 133, in DQN._train_step(self)
#     131 loss.backward()
#     132 nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
# --> 133 self.optimizer.step()
#     135 self.num_updates += 1
#     137 loss += loss.item()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/proj_rl/lib/python3.10/site-packages/torch/optim/optimizer.py:493, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     488         else:
#     489             raise RuntimeError(
#     490                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     491             )
# --> 493 out = func(*args, **kwargs)
#     494 self._optimizer_step_code()
#     496 # call optimizer step post hooks
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/proj_rl/lib/python3.10/site-packages/torch/optim/optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      89     torch.set_grad_enabled(self.defaults["differentiable"])
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#      93     torch._dynamo.graph_break()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/proj_rl/lib/python3.10/site-packages/torch/optim/adam.py:244, in Adam.step(self, closure)
#     232     beta1, beta2 = group["betas"]
#     234     has_complex = self._init_group(
#     235         group,
#     236         params_with_grad,
#    (...)
#     241         state_steps,
#     242     )
# --> 244     adam(
#     245         params_with_grad,
#     246         grads,
#     247         exp_avgs,
#     248         exp_avg_sqs,
#     249         max_exp_avg_sqs,
#     250         state_steps,
#     251         amsgrad=group["amsgrad"],
#     252         has_complex=has_complex,
#     253         beta1=beta1,
#     254         beta2=beta2,
#     255         lr=group["lr"],
#     256         weight_decay=group["weight_decay"],
#     257         eps=group["eps"],
#     258         maximize=group["maximize"],
#     259         foreach=group["foreach"],
#     260         capturable=group["capturable"],
#     261         differentiable=group["differentiable"],
#     262         fused=group["fused"],
#     263         grad_scale=getattr(self, "grad_scale", None),
#     264         found_inf=getattr(self, "found_inf", None),
#     265     )
#     267 return loss
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/proj_rl/lib/python3.10/site-packages/torch/optim/optimizer.py:154, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     152     return disabled_func(*args, **kwargs)
#     153 else:
# --> 154     return func(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/proj_rl/lib/python3.10/site-packages/torch/optim/adam.py:876, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     873 else:
#     874     func = _single_tensor_adam
# --> 876 func(
#     877     params,
#     878     grads,
#     879     exp_avgs,
#     880     exp_avg_sqs,
#     881     max_exp_avg_sqs,
#     882     state_steps,
#     883     amsgrad=amsgrad,
#     884     has_complex=has_complex,
#     885     beta1=beta1,
#     886     beta2=beta2,
#     887     lr=lr,
#     888     weight_decay=weight_decay,
#     889     eps=eps,
#     890     maximize=maximize,
#     891     capturable=capturable,
#     892     differentiable=differentiable,
#     893     grad_scale=grad_scale,
#     894     found_inf=found_inf,
#     895 )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/proj_rl/lib/python3.10/site-packages/torch/optim/adam.py:423, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     420     device_beta1 = beta1
#     422 # Decay the first and second moment running average coefficient
# --> 423 exp_avg.lerp_(grad, 1 - device_beta1)
#     425 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     427 if capturable or differentiable:
#
# KeyboardInterrupt:

# %%
best_params, best_score
# Out:
# ({'learning_rate': 0.001,
#   'buffer_size': 50000,
#   'learning_starts': 5000,
#   'batch_size': 128,
#   'tau': 1.0,
#   'gamma': 0.99,
#   'train_freq': 1,
#   'gradient_steps': 1,
#   'target_update_interval': 1000,
#   'exploration_fraction': 0.1,
#   'exploration_initial_eps': 0.1,
#   'exploration_final_eps': 0.1,
#   'max_grad_norm': 10,
#   'verbose': 1},
#  np.float64(7.71))

# %% [markdown]
# Estos params siguientes también se desempeñaron decentemente:

# %%
params1 = {
    "learning_rate": 0.001,
    "buffer_size": 50000,
    "learning_starts": 5000,
    "batch_size": 64,
    "tau": 1.0,
    "gamma": 0.99,
    "train_freq": 16,
    "gradient_steps": 4,
    "target_update_interval": 100,
    "exploration_fraction": 0.1,
    "exploration_initial_eps": 0.1,
    "exploration_final_eps": 0.1,
    "max_grad_norm": 10
}

params2 = {
    "learning_rate": 0.001,
    "buffer_size": 50000,
    "learning_starts": 5000,
    "batch_size": 64,
    "tau": 1.0,
    "gamma": 0.99,
    "train_freq": 16,
    "gradient_steps": 8,
    "target_update_interval": 1000,
    "exploration_fraction": 0.1,
    "exploration_initial_eps": 0.1,
    "exploration_final_eps": 0.1,
    "max_grad_norm": 10,
    "verbose": 1
}

# %%
params = [best_params, params1, params2]
rewards = []
losses = []

for param in params:
    seed = 42
    env = simple_tag_v3.parallel_env(render_mode='rgb_array', num_good=1, num_adversaries=3, num_obstacles=1, max_cycles=50, dynamic_rescaling = True)
    env.reset(seed=seed)
    agents = env.agents

    agent_dict = {
        agent: DQN(env, **param)
        for agent in agents if agent.startswith("adversary")
    }

    # Entrenar los agentes adversarios
    episode_rewards, episode_losses = learn_multiagent(env, agent_dict, total_timesteps=150000, log_interval=500)
    rewards.append(episode_rewards)
    losses.append(episode_losses)
# Out:
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 94
# |    time_elapsed     | 263
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 15.20 | loss: 0.7590 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 15.20 | loss: 0.2317 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 15.20 | loss: 0.4771 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 84
# |    time_elapsed     | 590
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 15.90 | loss: 2.2054 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 15.90 | loss: 1.3359 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 15.90 | loss: 2.4982 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1500
# |    fps              | 81
# |    time_elapsed     | 921
# |    total_timesteps  | 75000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 13.00 | loss: 1.2290 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 13.00 | loss: 2.7372 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 13.00 | loss: 2.9006 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2000
# |    fps              | 79
# |    time_elapsed     | 1251
# |    total_timesteps  | 100000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 9.40 | loss: 2.1126 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 9.40 | loss: 2.5036 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 9.40 | loss: 3.4770 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2500
# |    fps              | 79
# |    time_elapsed     | 1576
# |    total_timesteps  | 125000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.70 | loss: 3.4693 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.70 | loss: 4.4676 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.70 | loss: 4.5093 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3000
# |    fps              | 78
# |    time_elapsed     | 1900
# |    total_timesteps  | 150000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 6.80 | loss: 2.4651 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 6.80 | loss: 4.2825 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 6.80 | loss: 14.1364 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 265
# |    time_elapsed     | 94
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 14.50 | loss: 0.1727 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 14.50 | loss: 0.2213 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 14.50 | loss: 0.2049 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 245
# |    time_elapsed     | 203
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 14.10 | loss: 0.5079 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 14.10 | loss: 1.7555 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 14.10 | loss: 0.5177 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1500
# |    fps              | 239
# |    time_elapsed     | 313
# |    total_timesteps  | 75000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 9.00 | loss: 0.5465 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 9.00 | loss: 1.1159 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 9.00 | loss: 0.3086 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2000
# |    fps              | 236
# |    time_elapsed     | 422
# |    total_timesteps  | 100000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 11.80 | loss: 0.5216 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 11.80 | loss: 5.1816 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 11.80 | loss: 0.5603 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2500
# |    fps              | 235
# |    time_elapsed     | 530
# |    total_timesteps  | 125000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 4.40 | loss: 0.3976 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 4.40 | loss: 38.7691 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 4.40 | loss: 1.1488 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3000
# |    fps              | 234
# |    time_elapsed     | 639
# |    total_timesteps  | 150000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 5.50 | loss: 0.4986 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 5.50 | loss: 291.8391 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 5.50 | loss: 14.0928 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 169
# |    time_elapsed     | 147
# |    total_timesteps  | 25000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 9.40 | loss: 0.1492 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 9.40 | loss: 0.1574 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 9.40 | loss: 0.2827 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 154
# |    time_elapsed     | 324
# |    total_timesteps  | 50000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 15.40 | loss: 0.4548 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 15.40 | loss: 0.1603 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 15.40 | loss: 0.1191 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1500
# |    fps              | 149
# |    time_elapsed     | 501
# |    total_timesteps  | 75000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 17.20 | loss: 0.7291 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 17.20 | loss: 0.5293 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 17.20 | loss: 1.6743 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2000
# |    fps              | 147
# |    time_elapsed     | 678
# |    total_timesteps  | 100000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 18.80 | loss: 0.6781 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 18.80 | loss: 0.5092 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 18.80 | loss: 0.8166 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2500
# |    fps              | 146
# |    time_elapsed     | 855
# |    total_timesteps  | 125000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 18.20 | loss: 0.8595 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 18.20 | loss: 0.6748 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 18.20 | loss: 1.0572 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3000
# |    fps              | 145
# |    time_elapsed     | 1032
# |    total_timesteps  | 150000
# |    ep_len_mean      | 50
# | adversary_0 -> mean_ep_rew | 13.30 | loss: 1.2420 | eps: 0.100
# | adversary_1 -> mean_ep_rew | 13.30 | loss: 0.3509 | eps: 0.100
# | adversary_2 -> mean_ep_rew | 13.30 | loss: 0.7604 | eps: 0.100
# ----------------------------------

# %%
for reward, param in zip(rewards, params):
    print(f"Params: {param}")
    plot_total_rewards(reward)

for loss, param in zip(losses, params):
    print(f"Params: {param}")
    plot_total_rewards(loss)  # Graficar las pérdidas por episodio
# Out:
# Params: {'learning_rate': 0.001, 'buffer_size': 50000, 'learning_starts': 5000, 'batch_size': 128, 'tau': 1.0, 'gamma': 0.99, 'train_freq': 1, 'gradient_steps': 1, 'target_update_interval': 1000, 'exploration_fraction': 0.1, 'exploration_initial_eps': 0.1, 'exploration_final_eps': 0.1, 'max_grad_norm': 10, 'verbose': 1}
# Params: {'learning_rate': 0.001, 'buffer_size': 50000, 'learning_starts': 5000, 'batch_size': 64, 'tau': 1.0, 'gamma': 0.99, 'train_freq': 16, 'gradient_steps': 4, 'target_update_interval': 100, 'exploration_fraction': 0.1, 'exploration_initial_eps': 0.1, 'exploration_final_eps': 0.1, 'max_grad_norm': 10}
# Params: {'learning_rate': 0.001, 'buffer_size': 50000, 'learning_starts': 5000, 'batch_size': 64, 'tau': 1.0, 'gamma': 0.99, 'train_freq': 16, 'gradient_steps': 8, 'target_update_interval': 1000, 'exploration_fraction': 0.1, 'exploration_initial_eps': 0.1, 'exploration_final_eps': 0.1, 'max_grad_norm': 10, 'verbose': 1}
# Params: {'learning_rate': 0.001, 'buffer_size': 50000, 'learning_starts': 5000, 'batch_size': 128, 'tau': 1.0, 'gamma': 0.99, 'train_freq': 1, 'gradient_steps': 1, 'target_update_interval': 1000, 'exploration_fraction': 0.1, 'exploration_initial_eps': 0.1, 'exploration_final_eps': 0.1, 'max_grad_norm': 10, 'verbose': 1}
# Params: {'learning_rate': 0.001, 'buffer_size': 50000, 'learning_starts': 5000, 'batch_size': 64, 'tau': 1.0, 'gamma': 0.99, 'train_freq': 16, 'gradient_steps': 4, 'target_update_interval': 100, 'exploration_fraction': 0.1, 'exploration_initial_eps': 0.1, 'exploration_final_eps': 0.1, 'max_grad_norm': 10}
# Params: {'learning_rate': 0.001, 'buffer_size': 50000, 'learning_starts': 5000, 'batch_size': 64, 'tau': 1.0, 'gamma': 0.99, 'train_freq': 16, 'gradient_steps': 8, 'target_update_interval': 1000, 'exploration_fraction': 0.1, 'exploration_initial_eps': 0.1, 'exploration_final_eps': 0.1, 'max_grad_norm': 10, 'verbose': 1}

# %%
evaluate_multiagent_render_parallel(agent_dict, env, num_tests=5, save_path="multiagent_episode_3_obstacles_best.mp4", fps=5, max_steps=50)
# Out:
# Video guardado en: multiagent_episode_3_obstacles_best.mp4

# %%
env = simple_tag_v3.parallel_env(render_mode='rgb_array', num_good=1, num_adversaries=3, num_obstacles=2, max_cycles=50, dynamic_rescaling = True)
env.reset(seed=seed)
agents = env.agents
example_agent = env.agents[0]
print("Obs shape for", example_agent, ":", env.observation_space(example_agent).shape)
# Out:
# Obs shape for adversary_0 : (16,)
