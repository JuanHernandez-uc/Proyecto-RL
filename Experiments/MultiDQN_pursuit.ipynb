# %%
import numpy as np
import random
import torch
import torch.nn as nn
from collections import deque
from pettingzoo.sisl import pursuit_v4
import supersuit as ss

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F
import random
from collections import deque
import numpy as np
import time

class MLP(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_dim=128):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, x):
        return self.net(x)

class CNN(nn.Module):
    def __init__(self, input_shape, n_actions):
        super(CNN, self).__init__()
        c, h, w = input_shape  # c = canales, h = alto, w = ancho
        self.net = nn.Sequential(
            nn.Conv2d(c, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(64 * h * w, 128),
            nn.ReLU(),
            nn.Linear(128, n_actions)
        )

    def forward(self, x):
        return self.net(x)

class ReplayBuffer:
    def __init__(self, size):
        self.buffer = deque(maxlen=size)

    def add(self, *transition):
        self.buffer.append(transition)

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        return (
            torch.as_tensor(np.stack(states), dtype=torch.float32),
            torch.as_tensor(actions, dtype=torch.long),
            torch.as_tensor(rewards, dtype=torch.float32),
            torch.as_tensor(np.stack(next_states), dtype=torch.float32),
            torch.as_tensor(dones, dtype=torch.float32)
        )

    def __len__(self):
        return len(self.buffer)


class DQN:
    def __init__(self,
            env,
            learning_rate = 1e-3,
            buffer_size = 300000,
            learning_starts = 100,
            batch_size = 32,
            tau = 1.0,
            gamma = 0.99,
            train_freq = 4,
            gradient_steps = 1,
            target_update_interval = 10000,
            exploration_fraction = 0.1,
            exploration_initial_eps = 1.0,
            exploration_final_eps = 0.05,
            max_grad_norm = 10,
            verbose = 0
        ):
        
        self.env = env
        self.device = torch.device("mps" if torch.mps.is_available() else "cpu")
        example_agent = env.agents[0]
        self.obs_dim = env.observation_space(example_agent).shape[0]
        self.n_actions = env.action_space(example_agent).n

        self.policy = CNN(input_shape=(3, 7, 7), n_actions=self.n_actions).to(self.device)
        self.target_policy = CNN(input_shape=(3, 7, 7), n_actions=self.n_actions).to(self.device)
        self.target_policy.load_state_dict(self.policy.state_dict())
        self.target_policy.eval()

        self.optimizer = optim.Adam(self.policy.parameters(), lr=learning_rate, betas=(0.9, 0.999))
        self.replay_buffer = ReplayBuffer(buffer_size)

        self.learning_starts = learning_starts
        self.batch_size = batch_size
        self.tau = tau
        self.gamma = gamma
        self.train_freq = train_freq
        self.gradient_steps = gradient_steps
        self.target_update_interval = target_update_interval
        self.exploration_initial_eps = exploration_initial_eps
        self.exploration_final_eps = exploration_final_eps
        self.exploration_fraction = exploration_fraction
        self.max_grad_norm = max_grad_norm
        self.verbose = verbose

        self.epsilon = self.exploration_initial_eps
        self.last_loss = None
        self.num_updates = 0


    def _select_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.n_actions)
        state = torch.FloatTensor(state).permute(2, 0, 1).unsqueeze(0).to(self.device)  # (7,7,3) -> (1,3,7,7)
        with torch.no_grad():
            act_values = self.policy(state)
        return torch.argmax(act_values[0]).item()

    def _train_step(self):
        if len(self.replay_buffer) < self.batch_size:
            return

        self.policy.train()

        total_loss = 0
        for _ in range(self.gradient_steps):
            states, actions, rewards, next_states, dones = self.replay_buffer.sample(self.batch_size)
            # Permutar para que las dimensiones sean (batch_size, channels, height, width)
            states = states.permute(0, 3, 1, 2).to(self.device)
            actions = actions.to(self.device)
            rewards = rewards.to(self.device)
            next_states = next_states.permute(0, 3, 1, 2).to(self.device)
            dones = dones.to(self.device)

            q_values = self.policy(states).gather(1, actions.unsqueeze(1)).squeeze(1)

            with torch.no_grad():
                next_q_values = self.target_policy(next_states).max(1)[0]
                expected_q = rewards + self.gamma * next_q_values * (1 - dones)

            loss = F.smooth_l1_loss(q_values, expected_q)
            self.last_loss = loss.item()

            self.optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
            self.optimizer.step()

            self.num_updates += 1

            total_loss += loss.item()
        
        return total_loss / self.gradient_steps

    def learn(self, total_timesteps, log_interval=1000):
        obs, _ = self.env.reset()
        state = np.asarray(obs, dtype=np.float32)
        start_t  = time.perf_counter()
        ep_count = 0
        ep_lens  = deque(maxlen=100)
        ep_rews  = deque(maxlen=100)
        episode_reward = 0
        eps_decay_steps = int(self.exploration_fraction * total_timesteps)

        for t in range(1, total_timesteps + 1):
            self.total_timesteps = t
            self.epsilon = max(
                self.exploration_final_eps,
                self.exploration_initial_eps - (self.exploration_initial_eps - self.exploration_final_eps) * (t / eps_decay_steps)
            )

            action = self._select_action(state)
            next_state, reward, terminated, truncated, info = self.env.step(action)
            #reward = np.clip(reward, -1.0, 1.0)
            done = terminated or truncated
            next_state = np.asarray(next_state, dtype=np.float32)
            self.replay_buffer.add(state, action, reward, next_state, float(done))
            state = next_state
            episode_reward += reward

            if "episode" in info:
                ep_len = info["episode"]["l"]
                ep_rew = info["episode"]["r"]
                ep_lens.append(ep_len)
                ep_rews.append(ep_rew)
                ep_count += 1

            ## Fin del episodio
            if done:
                last_ep_reward = episode_reward
                obs, _ = self.env.reset()
                state = np.asarray(obs, dtype=np.float32)
                episode_reward = 0

            ## Cuándo se entrena la red
            if t > self.learning_starts and t % self.train_freq == 0:
                self._train_step()

            ## Sincronización de red target
            if self.num_updates > 0 and self.num_updates % self.target_update_interval == 0:
                self.target_policy.load_state_dict(self.policy.state_dict())
                self.target_policy.eval()

            if self.verbose and ep_count > 0 and ep_count % log_interval == 0 and done:
                fps = int(t / (time.perf_counter() - start_t))
                lr = self.optimizer.param_groups[0]["lr"]
                loss = self.last_loss if self.last_loss is not None else float("nan")
                print("----------------------------------")
                print(f"| rollout/            |          |")
                print(f"|    ep_len_mean      | {np.mean(ep_lens) if ep_lens else float('nan'):.0f}")
                print(f"|    ep_rew_mean      | {np.mean(ep_rews) if ep_rews else float('nan'):.0f}")
                print(f"|    exploration_rate | {self.epsilon:.3f}")
                print(f"| time/               |          |")
                print(f"|    episodes         | {ep_count}")
                print(f"|    fps              | {fps}")
                print(f"|    time_elapsed     | {int(time.perf_counter() - start_t)}")
                print(f"|    total_timesteps  | {t}")
                print(f"| train/              |          |")
                print(f"|    learning_rate    | {lr:.3g}")
                print(f"|    loss             | {loss:.4f}")
                print(f"|    n_updates        | {self.num_updates}")
                print("----------------------------------")

# %%
def learn_multiagent(env, agent_dict, total_timesteps, log_interval=1000):
    observations, _ = env.reset()
    episode_reward = {agent: 0 for agent in env.agents}
    ep_lens = deque(maxlen=100)
    ep_len = 0
    ep_rews = {agent: deque(maxlen=100) for agent in agent_dict}
    ep_count = 0
    t = 0
    start_t = time.perf_counter()

    eps_decay_steps = int(list(agent_dict.values())[0].exploration_fraction * total_timesteps)

    episode_rewards = []
    losses = []

    last_logged = -1

    while t < total_timesteps:
        actions = {}

        total_rewards = {agent: 0 for agent in env.agents}
        total_losses = {agent: 0 for agent in env.agents}

        for agent in env.agents:
            if agent in agent_dict:
                dqn = agent_dict[agent]
                dqn.epsilon = max(
                    dqn.exploration_final_eps,
                    dqn.exploration_initial_eps - (dqn.exploration_initial_eps - dqn.exploration_final_eps) * (t / eps_decay_steps)
                )
                action = dqn._select_action(observations[agent])
                actions[agent] = action
            else:
                actions[agent] = 0  # good agent se queda quieto

        next_obs, rewards, terminations, truncations, infos = env.step(actions)

        for agent in agent_dict:
            done = terminations[agent] or truncations[agent]
            dqn = agent_dict[agent]

            dqn.replay_buffer.add(
                np.array(observations[agent], dtype=np.float32),
                actions[agent],
                rewards[agent],
                np.array(next_obs[agent], dtype=np.float32),
                float(done)
            )
            episode_reward[agent] += rewards[agent]

            if t > dqn.learning_starts and t % dqn.train_freq == 0:
                loss = dqn._train_step()
                total_losses[agent] += loss if loss is not None else 0

            if dqn.num_updates > 0 and dqn.num_updates % dqn.target_update_interval == 0:
                dqn.target_policy.load_state_dict(dqn.policy.state_dict())
                dqn.target_policy.eval()

        losses.append(total_losses)

        t += 1
        observations = next_obs
        ep_len += 1
        # Fin de episodio
        if terminations["pursuer_0"] or truncations["pursuer_0"]:
            episode_rewards.append(episode_reward.copy())

            for agent in agent_dict:
                ep_rews[agent].append(episode_reward[agent])
                episode_reward[agent] = 0
            
            ep_lens.append(ep_len)  # si no tienes env.env_done_step puedes usar len(env.dones)
            ep_len = 0
            observations, _ = env.reset()
            ep_count += 1

        # Logging
        if ep_count > 0 and ep_count % log_interval == 0 and ep_count != last_logged:
            last_logged = ep_count
            fps = int(t / (time.perf_counter() - start_t))
            print("----------------------------------")
            print(f"| time/               |          |")
            print(f"|    episodes         | {ep_count}")
            print(f"|    fps              | {fps}")
            print(f"|    time_elapsed     | {int(time.perf_counter() - start_t)}")
            print(f"|    total_timesteps  | {t}")
            print(f"|    ep_len_mean      | {np.mean(ep_lens) if ep_lens else float('nan'):.0f}")
            for agent in agent_dict:
                dqn = agent_dict[agent]
                loss = dqn.last_loss if dqn.last_loss is not None else float("nan")
                print(f"| {agent} -> mean_ep_rew | {np.mean(ep_rews[agent]):.2f} | loss: {loss:.4f} | eps: {dqn.epsilon:.3f}")
            print("----------------------------------")

    return episode_rewards, losses

# %%
import matplotlib.pyplot as plt

def plot_total_rewards(rewards_dict_per_episode):
    """
    rewards_dict_per_episode: list de dicts por episodio, ej:
    [{agent_0: 10, agent_1: 12}, {agent_0: 5, agent_1: 7}, ...]
    """

    # llevar a cpu
    agent_names = rewards_dict_per_episode[0].keys()
    episode_count = len(rewards_dict_per_episode)

    for agent in agent_names:
        rewards = [episode[agent].cpu().item() if torch.is_tensor(episode[agent]) else episode[agent] for episode in rewards_dict_per_episode]
        plt.plot(rewards, label=agent)

    plt.xlabel("Episodio")
    plt.ylabel("Reward total por agente")
    plt.title("Recompensas por episodio")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Crear entorno paralelo
seed = 42
env = pursuit_v4.parallel_env(render_mode='rgb_array', x_size=7, y_size=7, n_pursuers=4, n_evaders=10)
env.reset(seed=seed)
agents = env.agents
example_agent = env.agents[0]
print("Obs shape for", example_agent, ":", env.observation_space(example_agent).shape)

dqn_params = {
    "learning_rate": 1e-3,
    "buffer_size": 5000,
    "learning_starts": 500,
    "batch_size": 128,
    "tau": 1.0,
    "gamma": 0.99,
    "train_freq": 1,
    "gradient_steps": 1,
    "target_update_interval": 500,
    "exploration_fraction": 0.1,
    "exploration_initial_eps": 1,
    "exploration_final_eps": 0.1,
    "max_grad_norm": 10,
    "verbose": 1,
}

# Inicializar agentes solo para los adversarios
agent_dict = {
    agent: DQN(env, **dqn_params)
    for agent in agents if agent.startswith("pursuer")
}

# Entrenar los agentes adversarios
episode_rewards, episode_losses = learn_multiagent(env, agent_dict, total_timesteps=50000, log_interval=10)
# Out:
# Obs shape for pursuer_0 : (7, 7, 3)
# ----------------------------------
# | time/               |          |
# |    episodes         | 10
# |    fps              | 38
# |    time_elapsed     | 130
# |    total_timesteps  | 5000
# |    ep_len_mean      | 500
# | pursuer_0 -> mean_ep_rew | -34.02 | loss: 0.0134 | eps: 0.100
# | pursuer_1 -> mean_ep_rew | -34.02 | loss: 0.0079 | eps: 0.100
# | pursuer_2 -> mean_ep_rew | -34.02 | loss: 0.0583 | eps: 0.100
# | pursuer_3 -> mean_ep_rew | -34.02 | loss: 0.0364 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 20
# |    fps              | 34
# |    time_elapsed     | 286
# |    total_timesteps  | 10000
# |    ep_len_mean      | 500
# | pursuer_0 -> mean_ep_rew | -30.96 | loss: 0.0061 | eps: 0.100
# | pursuer_1 -> mean_ep_rew | -30.96 | loss: 0.0087 | eps: 0.100
# | pursuer_2 -> mean_ep_rew | -30.96 | loss: 0.0244 | eps: 0.100
# | pursuer_3 -> mean_ep_rew | -30.96 | loss: 0.0138 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 30
# |    fps              | 34
# |    time_elapsed     | 433
# |    total_timesteps  | 14883
# |    ep_len_mean      | 496
# | pursuer_0 -> mean_ep_rew | -27.85 | loss: 0.0399 | eps: 0.100
# | pursuer_1 -> mean_ep_rew | -27.85 | loss: 0.0464 | eps: 0.100
# | pursuer_2 -> mean_ep_rew | -27.85 | loss: 0.0576 | eps: 0.100
# | pursuer_3 -> mean_ep_rew | -27.85 | loss: 0.0409 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 40
# |    fps              | 34
# |    time_elapsed     | 576
# |    total_timesteps  | 19674
# |    ep_len_mean      | 492
# | pursuer_0 -> mean_ep_rew | -26.01 | loss: 0.0543 | eps: 0.100
# | pursuer_1 -> mean_ep_rew | -26.01 | loss: 0.0423 | eps: 0.100
# | pursuer_2 -> mean_ep_rew | -26.01 | loss: 0.0480 | eps: 0.100
# | pursuer_3 -> mean_ep_rew | -26.01 | loss: 0.0840 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 50
# |    fps              | 33
# |    time_elapsed     | 726
# |    total_timesteps  | 24617
# |    ep_len_mean      | 492
# | pursuer_0 -> mean_ep_rew | -25.84 | loss: 0.0935 | eps: 0.100
# | pursuer_1 -> mean_ep_rew | -25.84 | loss: 0.0427 | eps: 0.100
# | pursuer_2 -> mean_ep_rew | -25.84 | loss: 0.0911 | eps: 0.100
# | pursuer_3 -> mean_ep_rew | -25.84 | loss: 0.0772 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 60
# |    fps              | 33
# |    time_elapsed     | 880
# |    total_timesteps  | 29564
# |    ep_len_mean      | 493
# | pursuer_0 -> mean_ep_rew | -25.67 | loss: 0.1313 | eps: 0.100
# | pursuer_1 -> mean_ep_rew | -25.67 | loss: 0.0792 | eps: 0.100
# | pursuer_2 -> mean_ep_rew | -25.67 | loss: 0.1910 | eps: 0.100
# | pursuer_3 -> mean_ep_rew | -25.67 | loss: 0.2144 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 70
# |    fps              | 33
# |    time_elapsed     | 1025
# |    total_timesteps  | 34329
# |    ep_len_mean      | 490
# | pursuer_0 -> mean_ep_rew | -25.23 | loss: 0.0879 | eps: 0.100
# | pursuer_1 -> mean_ep_rew | -25.23 | loss: 0.0372 | eps: 0.100
# | pursuer_2 -> mean_ep_rew | -25.23 | loss: 0.0885 | eps: 0.100
# | pursuer_3 -> mean_ep_rew | -25.23 | loss: 0.0593 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 80
# |    fps              | 33
# |    time_elapsed     | 1179
# |    total_timesteps  | 39284
# |    ep_len_mean      | 491
# | pursuer_0 -> mean_ep_rew | -25.46 | loss: 0.0703 | eps: 0.100
# | pursuer_1 -> mean_ep_rew | -25.46 | loss: 0.0594 | eps: 0.100
# | pursuer_2 -> mean_ep_rew | -25.46 | loss: 0.0798 | eps: 0.100
# | pursuer_3 -> mean_ep_rew | -25.46 | loss: 0.1327 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 90
# |    fps              | 33
# |    time_elapsed     | 1337
# |    total_timesteps  | 44243
# |    ep_len_mean      | 492
# | pursuer_0 -> mean_ep_rew | -25.50 | loss: 0.1140 | eps: 0.100
# | pursuer_1 -> mean_ep_rew | -25.50 | loss: 0.0476 | eps: 0.100
# | pursuer_2 -> mean_ep_rew | -25.50 | loss: 0.1419 | eps: 0.100
# | pursuer_3 -> mean_ep_rew | -25.50 | loss: 0.0661 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 33
# |    time_elapsed     | 1491
# |    total_timesteps  | 49212
# |    ep_len_mean      | 492
# | pursuer_0 -> mean_ep_rew | -25.63 | loss: 0.1581 | eps: 0.100
# | pursuer_1 -> mean_ep_rew | -25.63 | loss: 0.0887 | eps: 0.100
# | pursuer_2 -> mean_ep_rew | -25.63 | loss: 0.0566 | eps: 0.100
# | pursuer_3 -> mean_ep_rew | -25.63 | loss: 0.0520 | eps: 0.100
# ----------------------------------

# %%
plot_total_rewards(episode_rewards)
plot_total_rewards(episode_losses)  # Graficar las pérdidas por episodio

# %%
def evaluate_agent_parallel(env, agent_dict, episodes=5):
    rewards = []

    for agent in agent_dict.values():
        agent.epsilon = 0  # Evaluación sin exploración

    for _ in range(episodes):
        observations, _ = env.reset()
        total_rewards = {agent: 0 for agent in env.agents}
        terminated = {agent: False for agent in env.agents}
        truncated = {agent: False for agent in env.agents}

        while not all(terminated[agent] or truncated[agent] for agent in env.agents):
            actions = {}
            for agent in env.agents:
                if terminated[agent] or truncated[agent]:
                    continue
                if agent in agent_dict:
                    actions[agent] = agent_dict[agent]._select_action(observations[agent])
                else:
                    actions[agent] = 0  # El agente bueno se queda quieto

            observations, rewards_step, terminated_step, truncated_step, _ = env.step(actions)

            for agent in env.agents:
                total_rewards[agent] += rewards_step[agent]
                terminated[agent] = terminated_step[agent]
                truncated[agent] = truncated_step[agent]

        rewards.append(total_rewards)

    return rewards

# %%
rewards_2 = evaluate_agent_parallel(env, agent_dict, episodes = 20)
plot_total_rewards(rewards_2)

# %%
import imageio
import numpy as np
from PIL import Image

def evaluate_multiagent_render_parallel(agent_dict, env, num_tests=1, save_path="multiagent_episode.mp4", fps=5, max_steps=500):
    all_frames = []

    # Política determinista: desactiva exploración
    for agent in agent_dict.values():
        agent.epsilon = 0.0

    for _ in range(num_tests):
        observations, _ = env.reset()
        terminated = {agent: False for agent in env.agents}
        truncated = {agent: False for agent in env.agents}
        frames = []
        step_count = 0

        while not all(terminated[agent] or truncated[agent] for agent in env.agents) and step_count < max_steps:
            actions = {}
            for agent in env.agents:
                if terminated[agent] or truncated[agent]:
                    continue
                if agent in agent_dict:
                    actions[agent] = agent_dict[agent]._select_action(observations[agent])
                else:
                    actions[agent] = 0  # agente bueno quieto

            observations, _, terminated_step, truncated_step, _ = env.step(actions)

            for agent in env.agents:
                terminated[agent] = terminated_step[agent]
                truncated[agent] = truncated_step[agent]

            frame = env.render()
            frame_resized = np.array(Image.fromarray(frame).resize((240, 240)))
            frames.append(frame_resized)
            step_count += 1

        all_frames.extend(frames + [frames[-1]] * 5)  # padding final

    imageio.mimsave(save_path, all_frames, fps=fps)
    print(f"Video guardado en: {save_path}")

# %%
evaluate_multiagent_render_parallel(agent_dict, env, num_tests=5, save_path="multiagent_episode_purusuit.mp4", fps=5, max_steps=50)
# Out:
# Video guardado en: multiagent_episode_purusuit.mp4

# %% [markdown]
# # 2 Agents

# %%
# Crear entorno paralelo
seed = 42
env = simple_spread_v3.parallel_env(render_mode='rgb_array', N=2, local_ratio = 0.5, max_cycles=25, dynamic_rescaling=True)
env.reset(seed=seed)
agents = env.agents

dqn_params = {
    "learning_rate": 1e-3,
    "buffer_size": 10000,
    "learning_starts": 1000,
    "batch_size": 128,
    "tau": 1.0,
    "gamma": 0.99,
    "train_freq": 16,
    "gradient_steps": 4,
    "target_update_interval": 1000,
    "exploration_fraction": 0.1,
    "exploration_initial_eps": 1,
    "exploration_final_eps": 0.1,
    "max_grad_norm": 10,
    "verbose": 1,
}

# Inicializar agentes solo para los adversarios
agent_dict = {
    agent: DQN(env, **dqn_params)
    for agent in agents if agent.startswith("agent")
}

# Entrenar los agentes adversarios
episode_rewards2, episode_losses2 = learn_multiagent(env, agent_dict, total_timesteps=100000, log_interval=100)
# Out:
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 640
# |    time_elapsed     | 3
# |    total_timesteps  | 2500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -21.82 | loss: 0.0091 | eps: 0.775
# | agent_1 -> mean_ep_rew | -21.82 | loss: 0.0066 | eps: 0.775
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 501
# |    time_elapsed     | 9
# |    total_timesteps  | 5000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -21.66 | loss: 0.0040 | eps: 0.550
# | agent_1 -> mean_ep_rew | -21.66 | loss: 0.0043 | eps: 0.550
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 435
# |    time_elapsed     | 17
# |    total_timesteps  | 7500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -23.23 | loss: 0.0167 | eps: 0.325
# | agent_1 -> mean_ep_rew | -23.23 | loss: 0.0126 | eps: 0.325
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 400
# |    time_elapsed     | 24
# |    total_timesteps  | 10000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -21.08 | loss: 0.0341 | eps: 0.100
# | agent_1 -> mean_ep_rew | -21.08 | loss: 0.0881 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 386
# |    time_elapsed     | 32
# |    total_timesteps  | 12500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -18.32 | loss: 0.0392 | eps: 0.100
# | agent_1 -> mean_ep_rew | -18.32 | loss: 0.0715 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 380
# |    time_elapsed     | 39
# |    total_timesteps  | 15000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -17.40 | loss: 0.0807 | eps: 0.100
# | agent_1 -> mean_ep_rew | -17.40 | loss: 0.0865 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 376
# |    time_elapsed     | 46
# |    total_timesteps  | 17500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -17.12 | loss: 0.0879 | eps: 0.100
# | agent_1 -> mean_ep_rew | -17.12 | loss: 0.0701 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 373
# |    time_elapsed     | 53
# |    total_timesteps  | 20000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -16.60 | loss: 0.0249 | eps: 0.100
# | agent_1 -> mean_ep_rew | -16.60 | loss: 0.0494 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 370
# |    time_elapsed     | 60
# |    total_timesteps  | 22500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -14.50 | loss: 0.1188 | eps: 0.100
# | agent_1 -> mean_ep_rew | -14.50 | loss: 0.0786 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 368
# |    time_elapsed     | 67
# |    total_timesteps  | 25000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -15.46 | loss: 0.0802 | eps: 0.100
# | agent_1 -> mean_ep_rew | -15.46 | loss: 0.0932 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 367
# |    time_elapsed     | 74
# |    total_timesteps  | 27500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -14.21 | loss: 0.1100 | eps: 0.100
# | agent_1 -> mean_ep_rew | -14.21 | loss: 0.1344 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 366
# |    time_elapsed     | 81
# |    total_timesteps  | 30000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -13.65 | loss: 0.1054 | eps: 0.100
# | agent_1 -> mean_ep_rew | -13.65 | loss: 0.1384 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 365
# |    time_elapsed     | 89
# |    total_timesteps  | 32500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -13.47 | loss: 0.1156 | eps: 0.100
# | agent_1 -> mean_ep_rew | -13.47 | loss: 0.0680 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1400
# |    fps              | 364
# |    time_elapsed     | 96
# |    total_timesteps  | 35000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -13.42 | loss: 0.1076 | eps: 0.100
# | agent_1 -> mean_ep_rew | -13.42 | loss: 0.1326 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1500
# |    fps              | 363
# |    time_elapsed     | 103
# |    total_timesteps  | 37500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -12.52 | loss: 0.2070 | eps: 0.100
# | agent_1 -> mean_ep_rew | -12.52 | loss: 0.1523 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1600
# |    fps              | 362
# |    time_elapsed     | 110
# |    total_timesteps  | 40000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.18 | loss: 0.0386 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.18 | loss: 0.1961 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1700
# |    fps              | 362
# |    time_elapsed     | 117
# |    total_timesteps  | 42500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -12.50 | loss: 0.1985 | eps: 0.100
# | agent_1 -> mean_ep_rew | -12.50 | loss: 0.0401 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1800
# |    fps              | 361
# |    time_elapsed     | 124
# |    total_timesteps  | 45000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.51 | loss: 0.1106 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.51 | loss: 0.0838 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1900
# |    fps              | 361
# |    time_elapsed     | 131
# |    total_timesteps  | 47500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -10.91 | loss: 0.0858 | eps: 0.100
# | agent_1 -> mean_ep_rew | -10.91 | loss: 0.0770 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2000
# |    fps              | 360
# |    time_elapsed     | 138
# |    total_timesteps  | 50000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -12.33 | loss: 0.0951 | eps: 0.100
# | agent_1 -> mean_ep_rew | -12.33 | loss: 0.1466 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2100
# |    fps              | 360
# |    time_elapsed     | 145
# |    total_timesteps  | 52500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.05 | loss: 0.0451 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.05 | loss: 0.0807 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2200
# |    fps              | 360
# |    time_elapsed     | 152
# |    total_timesteps  | 55000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.36 | loss: 0.0566 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.36 | loss: 0.1483 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2300
# |    fps              | 360
# |    time_elapsed     | 159
# |    total_timesteps  | 57500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.21 | loss: 0.1086 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.21 | loss: 0.1739 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2400
# |    fps              | 359
# |    time_elapsed     | 166
# |    total_timesteps  | 60000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -10.65 | loss: 0.0511 | eps: 0.100
# | agent_1 -> mean_ep_rew | -10.65 | loss: 0.2643 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2500
# |    fps              | 359
# |    time_elapsed     | 173
# |    total_timesteps  | 62500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.09 | loss: 0.0973 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.09 | loss: 0.1205 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2600
# |    fps              | 359
# |    time_elapsed     | 180
# |    total_timesteps  | 65000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.67 | loss: 0.0357 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.67 | loss: 0.0800 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2700
# |    fps              | 359
# |    time_elapsed     | 187
# |    total_timesteps  | 67500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.06 | loss: 0.2324 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.06 | loss: 0.2005 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2800
# |    fps              | 359
# |    time_elapsed     | 194
# |    total_timesteps  | 70000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.69 | loss: 0.0666 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.69 | loss: 0.2589 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2900
# |    fps              | 358
# |    time_elapsed     | 201
# |    total_timesteps  | 72500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -10.60 | loss: 0.0966 | eps: 0.100
# | agent_1 -> mean_ep_rew | -10.60 | loss: 0.3442 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3000
# |    fps              | 358
# |    time_elapsed     | 209
# |    total_timesteps  | 75000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -10.74 | loss: 0.0898 | eps: 0.100
# | agent_1 -> mean_ep_rew | -10.74 | loss: 0.1196 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3100
# |    fps              | 358
# |    time_elapsed     | 216
# |    total_timesteps  | 77500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -10.94 | loss: 0.0592 | eps: 0.100
# | agent_1 -> mean_ep_rew | -10.94 | loss: 0.0944 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3200
# |    fps              | 358
# |    time_elapsed     | 223
# |    total_timesteps  | 80000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.73 | loss: 0.0979 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.73 | loss: 0.0989 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3300
# |    fps              | 358
# |    time_elapsed     | 230
# |    total_timesteps  | 82500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.15 | loss: 0.1632 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.15 | loss: 0.0861 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3400
# |    fps              | 358
# |    time_elapsed     | 237
# |    total_timesteps  | 85000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.13 | loss: 0.2332 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.13 | loss: 0.0936 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3500
# |    fps              | 358
# |    time_elapsed     | 244
# |    total_timesteps  | 87500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -9.94 | loss: 0.0382 | eps: 0.100
# | agent_1 -> mean_ep_rew | -9.94 | loss: 0.1254 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3600
# |    fps              | 358
# |    time_elapsed     | 251
# |    total_timesteps  | 90000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -10.74 | loss: 0.1906 | eps: 0.100
# | agent_1 -> mean_ep_rew | -10.74 | loss: 0.1308 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3700
# |    fps              | 358
# |    time_elapsed     | 258
# |    total_timesteps  | 92500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -10.42 | loss: 0.1879 | eps: 0.100
# | agent_1 -> mean_ep_rew | -10.42 | loss: 0.1174 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3800
# |    fps              | 357
# |    time_elapsed     | 265
# |    total_timesteps  | 95000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.00 | loss: 0.0944 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.00 | loss: 0.1092 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3900
# |    fps              | 357
# |    time_elapsed     | 272
# |    total_timesteps  | 97500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.40 | loss: 0.1346 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.40 | loss: 0.0684 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 4000
# |    fps              | 357
# |    time_elapsed     | 279
# |    total_timesteps  | 100000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -11.33 | loss: 0.1447 | eps: 0.100
# | agent_1 -> mean_ep_rew | -11.33 | loss: 0.1467 | eps: 0.100
# ----------------------------------

# %%
plot_total_rewards(episode_rewards2)
plot_total_rewards(episode_losses2)  # Graficar las pérdidas por episodio

# %%
rewards_2 = evaluate_agent_parallel(env, agent_dict, episodes=20)
plot_total_rewards(rewards_2)

# %%
evaluate_multiagent_render_parallel(agent_dict, env, num_tests=5, save_path="multiagent_episode_simple_spread2.mp4", fps=5, max_steps=50)
# Out:
# Video guardado en: multiagent_episode_simple_spread2.mp4

# %% [markdown]
# # 3 Agents

# %%
# Crear entorno paralelo
seed = 42
env = simple_spread_v3.parallel_env(render_mode='rgb_array', N = 3, local_ratio = 0.5, max_cycles=25, dynamic_rescaling=True)
env.reset(seed=seed)
agents = env.agents

dqn_params = {
    "learning_rate": 1e-3,
    "buffer_size": 100000,
    "learning_starts": 1000,
    "batch_size": 128,
    "tau": 1.0,
    "gamma": 0.99,
    "train_freq": 16,
    "gradient_steps": 4,
    "target_update_interval": 1000,
    "exploration_fraction": 0.1,
    "exploration_initial_eps": 1,
    "exploration_final_eps": 0.1,
    "max_grad_norm": 10,
    "verbose": 1,
}

# Inicializar agentes solo para los adversarios
agent_dict = {
    agent: DQN(env, **dqn_params)
    for agent in agents if agent.startswith("agent")
}

# Entrenar los agentes adversarios
episode_rewards3, episode_losses3 = learn_multiagent(env, agent_dict, total_timesteps=100000, log_interval=100)
# Out:
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 492
# |    time_elapsed     | 5
# |    total_timesteps  | 2500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -26.34 | loss: 0.0213 | eps: 0.775
# | agent_1 -> mean_ep_rew | -26.40 | loss: 0.0144 | eps: 0.775
# | agent_2 -> mean_ep_rew | -26.30 | loss: 0.0198 | eps: 0.775
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 355
# |    time_elapsed     | 14
# |    total_timesteps  | 5000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -27.28 | loss: 0.0148 | eps: 0.550
# | agent_1 -> mean_ep_rew | -27.31 | loss: 0.0126 | eps: 0.550
# | agent_2 -> mean_ep_rew | -27.38 | loss: 0.0110 | eps: 0.550
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 319
# |    time_elapsed     | 23
# |    total_timesteps  | 7500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -29.08 | loss: 0.0376 | eps: 0.325
# | agent_1 -> mean_ep_rew | -29.13 | loss: 0.0263 | eps: 0.325
# | agent_2 -> mean_ep_rew | -29.08 | loss: 0.0362 | eps: 0.325
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 295
# |    time_elapsed     | 33
# |    total_timesteps  | 10000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -29.97 | loss: 0.1342 | eps: 0.100
# | agent_1 -> mean_ep_rew | -30.16 | loss: 0.0715 | eps: 0.100
# | agent_2 -> mean_ep_rew | -30.09 | loss: 0.0711 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 281
# |    time_elapsed     | 44
# |    total_timesteps  | 12500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -27.71 | loss: 0.1022 | eps: 0.100
# | agent_1 -> mean_ep_rew | -27.74 | loss: 0.1200 | eps: 0.100
# | agent_2 -> mean_ep_rew | -27.66 | loss: 0.0568 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 271
# |    time_elapsed     | 55
# |    total_timesteps  | 15000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -26.24 | loss: 0.1171 | eps: 0.100
# | agent_1 -> mean_ep_rew | -26.17 | loss: 0.1852 | eps: 0.100
# | agent_2 -> mean_ep_rew | -26.19 | loss: 0.0755 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 265
# |    time_elapsed     | 65
# |    total_timesteps  | 17500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -25.35 | loss: 0.2764 | eps: 0.100
# | agent_1 -> mean_ep_rew | -25.38 | loss: 0.2229 | eps: 0.100
# | agent_2 -> mean_ep_rew | -25.45 | loss: 0.2132 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 261
# |    time_elapsed     | 76
# |    total_timesteps  | 20000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -24.04 | loss: 0.3186 | eps: 0.100
# | agent_1 -> mean_ep_rew | -24.11 | loss: 0.1332 | eps: 0.100
# | agent_2 -> mean_ep_rew | -24.22 | loss: 0.1235 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 257
# |    time_elapsed     | 87
# |    total_timesteps  | 22500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -23.84 | loss: 0.2494 | eps: 0.100
# | agent_1 -> mean_ep_rew | -23.80 | loss: 0.2286 | eps: 0.100
# | agent_2 -> mean_ep_rew | -23.79 | loss: 0.3164 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 255
# |    time_elapsed     | 97
# |    total_timesteps  | 25000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -22.15 | loss: 0.3816 | eps: 0.100
# | agent_1 -> mean_ep_rew | -22.13 | loss: 0.1642 | eps: 0.100
# | agent_2 -> mean_ep_rew | -22.13 | loss: 0.2273 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 252
# |    time_elapsed     | 108
# |    total_timesteps  | 27500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -22.48 | loss: 0.3827 | eps: 0.100
# | agent_1 -> mean_ep_rew | -22.33 | loss: 0.4753 | eps: 0.100
# | agent_2 -> mean_ep_rew | -22.43 | loss: 0.2124 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 251
# |    time_elapsed     | 119
# |    total_timesteps  | 30000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -22.36 | loss: 0.2390 | eps: 0.100
# | agent_1 -> mean_ep_rew | -22.48 | loss: 0.0700 | eps: 0.100
# | agent_2 -> mean_ep_rew | -22.30 | loss: 0.3011 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 249
# |    time_elapsed     | 130
# |    total_timesteps  | 32500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -21.98 | loss: 0.1980 | eps: 0.100
# | agent_1 -> mean_ep_rew | -21.86 | loss: 0.1385 | eps: 0.100
# | agent_2 -> mean_ep_rew | -21.89 | loss: 0.3453 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1400
# |    fps              | 248
# |    time_elapsed     | 140
# |    total_timesteps  | 35000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -22.52 | loss: 0.0636 | eps: 0.100
# | agent_1 -> mean_ep_rew | -22.38 | loss: 0.2402 | eps: 0.100
# | agent_2 -> mean_ep_rew | -22.28 | loss: 0.5349 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1500
# |    fps              | 247
# |    time_elapsed     | 151
# |    total_timesteps  | 37500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -21.36 | loss: 0.4493 | eps: 0.100
# | agent_1 -> mean_ep_rew | -21.25 | loss: 0.3578 | eps: 0.100
# | agent_2 -> mean_ep_rew | -21.28 | loss: 0.3782 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1600
# |    fps              | 246
# |    time_elapsed     | 162
# |    total_timesteps  | 40000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.96 | loss: 0.2906 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.90 | loss: 0.3043 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.91 | loss: 0.4670 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1700
# |    fps              | 245
# |    time_elapsed     | 173
# |    total_timesteps  | 42500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.80 | loss: 0.2612 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.63 | loss: 0.2500 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.71 | loss: 0.4043 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1800
# |    fps              | 244
# |    time_elapsed     | 183
# |    total_timesteps  | 45000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.27 | loss: 0.4024 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.29 | loss: 0.1919 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.08 | loss: 0.3866 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1900
# |    fps              | 244
# |    time_elapsed     | 194
# |    total_timesteps  | 47500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.66 | loss: 0.5120 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.75 | loss: 0.3618 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.48 | loss: 0.6575 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2000
# |    fps              | 243
# |    time_elapsed     | 205
# |    total_timesteps  | 50000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.66 | loss: 0.3667 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.68 | loss: 0.7561 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.59 | loss: 0.3871 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2100
# |    fps              | 243
# |    time_elapsed     | 215
# |    total_timesteps  | 52500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.61 | loss: 0.2074 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.65 | loss: 0.6039 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.66 | loss: 0.2750 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2200
# |    fps              | 242
# |    time_elapsed     | 226
# |    total_timesteps  | 55000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.10 | loss: 0.2503 | eps: 0.100
# | agent_1 -> mean_ep_rew | -18.95 | loss: 0.4718 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.19 | loss: 0.3426 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2300
# |    fps              | 242
# |    time_elapsed     | 237
# |    total_timesteps  | 57500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.99 | loss: 0.3138 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.96 | loss: 0.5238 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.86 | loss: 0.3585 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2400
# |    fps              | 241
# |    time_elapsed     | 248
# |    total_timesteps  | 60000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.34 | loss: 0.5456 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.45 | loss: 0.1619 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.50 | loss: 0.5480 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2500
# |    fps              | 241
# |    time_elapsed     | 259
# |    total_timesteps  | 62500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.50 | loss: 0.4645 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.34 | loss: 0.5744 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.24 | loss: 0.4094 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2600
# |    fps              | 240
# |    time_elapsed     | 269
# |    total_timesteps  | 65000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.16 | loss: 0.5495 | eps: 0.100
# | agent_1 -> mean_ep_rew | -18.97 | loss: 0.2663 | eps: 0.100
# | agent_2 -> mean_ep_rew | -18.95 | loss: 0.6086 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2700
# |    fps              | 240
# |    time_elapsed     | 280
# |    total_timesteps  | 67500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.03 | loss: 0.3238 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.16 | loss: 0.4001 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.95 | loss: 0.5329 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2800
# |    fps              | 240
# |    time_elapsed     | 291
# |    total_timesteps  | 70000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.25 | loss: 0.3724 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.18 | loss: 0.5467 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.11 | loss: 0.4288 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2900
# |    fps              | 239
# |    time_elapsed     | 302
# |    total_timesteps  | 72500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.62 | loss: 0.5274 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.59 | loss: 0.3697 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.45 | loss: 0.5088 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3000
# |    fps              | 239
# |    time_elapsed     | 313
# |    total_timesteps  | 75000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.14 | loss: 0.3002 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.17 | loss: 0.3454 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.04 | loss: 0.4850 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3100
# |    fps              | 239
# |    time_elapsed     | 323
# |    total_timesteps  | 77500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -18.18 | loss: 0.7366 | eps: 0.100
# | agent_1 -> mean_ep_rew | -18.07 | loss: 0.2471 | eps: 0.100
# | agent_2 -> mean_ep_rew | -18.06 | loss: 0.3386 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3200
# |    fps              | 238
# |    time_elapsed     | 334
# |    total_timesteps  | 80000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.26 | loss: 0.4221 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.13 | loss: 0.6750 | eps: 0.100
# | agent_2 -> mean_ep_rew | -18.97 | loss: 0.3863 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3300
# |    fps              | 238
# |    time_elapsed     | 345
# |    total_timesteps  | 82500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.71 | loss: 0.5154 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.45 | loss: 0.4955 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.62 | loss: 0.4281 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3400
# |    fps              | 238
# |    time_elapsed     | 356
# |    total_timesteps  | 85000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -18.84 | loss: 0.5594 | eps: 0.100
# | agent_1 -> mean_ep_rew | -18.72 | loss: 0.4070 | eps: 0.100
# | agent_2 -> mean_ep_rew | -18.87 | loss: 0.1053 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3500
# |    fps              | 238
# |    time_elapsed     | 367
# |    total_timesteps  | 87500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -18.98 | loss: 0.4453 | eps: 0.100
# | agent_1 -> mean_ep_rew | -18.85 | loss: 0.6166 | eps: 0.100
# | agent_2 -> mean_ep_rew | -18.82 | loss: 0.6304 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3600
# |    fps              | 237
# |    time_elapsed     | 378
# |    total_timesteps  | 90000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -18.60 | loss: 0.7966 | eps: 0.100
# | agent_1 -> mean_ep_rew | -18.55 | loss: 0.7275 | eps: 0.100
# | agent_2 -> mean_ep_rew | -18.60 | loss: 0.5025 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3700
# |    fps              | 237
# |    time_elapsed     | 389
# |    total_timesteps  | 92500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.38 | loss: 0.5591 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.24 | loss: 0.4969 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.25 | loss: 0.6316 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3800
# |    fps              | 237
# |    time_elapsed     | 400
# |    total_timesteps  | 95000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.83 | loss: 0.5112 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.69 | loss: 0.6564 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.73 | loss: 0.3076 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3900
# |    fps              | 237
# |    time_elapsed     | 411
# |    total_timesteps  | 97500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.11 | loss: 0.4599 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.08 | loss: 0.5551 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.05 | loss: 0.5731 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 4000
# |    fps              | 236
# |    time_elapsed     | 422
# |    total_timesteps  | 100000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.19 | loss: 0.5432 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.12 | loss: 0.5985 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.11 | loss: 1.2292 | eps: 0.100
# ----------------------------------

# %%
plot_total_rewards(episode_rewards3)
plot_total_rewards(episode_losses3)  # Graficar las pérdidas por episodio

# %%
rewards_3 = evaluate_agent_parallel(env, agent_dict, episodes=20)
plot_total_rewards(rewards_3)

# %%
evaluate_multiagent_render_parallel(agent_dict, env, num_tests=5, save_path="multiagent_episode_simple_spread3.mp4", fps=5, max_steps=50)
# Out:
# Video guardado en: multiagent_episode_simple_spread3.mp4

# %% [markdown]
# ## 3 agents and obstacle

# %%
# Crear entorno paralelo
seed = 42
env = simple_spread_v3.parallel_env(render_mode='rgb_array', N=3, max_cycles=25, local_ratio=0.5, dynamic_rescaling=True)
env.reset(seed=seed)
agents = env.agents

dqn_params = {
    "learning_rate": 1e-4,
    "buffer_size": 1000000,
    "learning_starts": 5000,
    "batch_size": 128,
    "tau": 1.0,
    "gamma": 0.99,
    "train_freq": 16,
    "gradient_steps": 4,
    "target_update_interval": 2000,
    "exploration_fraction": 0.1,
    "exploration_initial_eps": 1,
    "exploration_final_eps": 0.1,
    "max_grad_norm": 10,
    "verbose": 1,
}

# Inicializar agentes solo para los adversarios
agent_dict = {
    agent: DQN(env, **dqn_params)
    for agent in agents if agent.startswith("agent")
}

# Entrenar los agentes adversarios
episode_rewards4, episode_losses4 = learn_multiagent(env, agent_dict, total_timesteps=150000, log_interval=100)
# Out:
# ----------------------------------
# | time/               |          |
# |    episodes         | 100
# |    fps              | 3643
# |    time_elapsed     | 0
# |    total_timesteps  | 2500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -26.26 | loss: nan | eps: 0.850
# | agent_1 -> mean_ep_rew | -26.21 | loss: nan | eps: 0.850
# | agent_2 -> mean_ep_rew | -26.18 | loss: nan | eps: 0.850
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 200
# |    fps              | 2617
# |    time_elapsed     | 1
# |    total_timesteps  | 5000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -28.00 | loss: nan | eps: 0.700
# | agent_1 -> mean_ep_rew | -27.95 | loss: nan | eps: 0.700
# | agent_2 -> mean_ep_rew | -27.99 | loss: nan | eps: 0.700
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 300
# |    fps              | 628
# |    time_elapsed     | 11
# |    total_timesteps  | 7500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -30.10 | loss: 0.0736 | eps: 0.550
# | agent_1 -> mean_ep_rew | -30.11 | loss: 0.0491 | eps: 0.550
# | agent_2 -> mean_ep_rew | -30.16 | loss: 0.0482 | eps: 0.550
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 400
# |    fps              | 445
# |    time_elapsed     | 22
# |    total_timesteps  | 10000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -28.62 | loss: 0.0475 | eps: 0.400
# | agent_1 -> mean_ep_rew | -28.74 | loss: 0.0531 | eps: 0.400
# | agent_2 -> mean_ep_rew | -28.68 | loss: 0.0525 | eps: 0.400
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 500
# |    fps              | 380
# |    time_elapsed     | 32
# |    total_timesteps  | 12500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -28.25 | loss: 0.0451 | eps: 0.250
# | agent_1 -> mean_ep_rew | -28.30 | loss: 0.0492 | eps: 0.250
# | agent_2 -> mean_ep_rew | -28.22 | loss: 0.0539 | eps: 0.250
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 600
# |    fps              | 342
# |    time_elapsed     | 43
# |    total_timesteps  | 15000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -29.23 | loss: 0.0697 | eps: 0.100
# | agent_1 -> mean_ep_rew | -29.11 | loss: 0.0966 | eps: 0.100
# | agent_2 -> mean_ep_rew | -29.15 | loss: 0.0666 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 700
# |    fps              | 316
# |    time_elapsed     | 55
# |    total_timesteps  | 17500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -31.14 | loss: 0.0687 | eps: 0.100
# | agent_1 -> mean_ep_rew | -30.99 | loss: 0.1168 | eps: 0.100
# | agent_2 -> mean_ep_rew | -31.03 | loss: 0.0649 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 800
# |    fps              | 299
# |    time_elapsed     | 66
# |    total_timesteps  | 20000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -27.25 | loss: 0.0709 | eps: 0.100
# | agent_1 -> mean_ep_rew | -27.06 | loss: 0.0721 | eps: 0.100
# | agent_2 -> mean_ep_rew | -27.22 | loss: 0.0779 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 900
# |    fps              | 286
# |    time_elapsed     | 78
# |    total_timesteps  | 22500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -28.27 | loss: 0.0524 | eps: 0.100
# | agent_1 -> mean_ep_rew | -28.28 | loss: 0.1260 | eps: 0.100
# | agent_2 -> mean_ep_rew | -28.36 | loss: 0.1030 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1000
# |    fps              | 276
# |    time_elapsed     | 90
# |    total_timesteps  | 25000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -23.78 | loss: 0.1786 | eps: 0.100
# | agent_1 -> mean_ep_rew | -23.76 | loss: 0.1812 | eps: 0.100
# | agent_2 -> mean_ep_rew | -23.79 | loss: 0.1340 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1100
# |    fps              | 268
# |    time_elapsed     | 102
# |    total_timesteps  | 27500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -26.90 | loss: 0.1838 | eps: 0.100
# | agent_1 -> mean_ep_rew | -26.99 | loss: 0.1129 | eps: 0.100
# | agent_2 -> mean_ep_rew | -26.84 | loss: 0.1419 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1200
# |    fps              | 261
# |    time_elapsed     | 114
# |    total_timesteps  | 30000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -24.37 | loss: 0.1450 | eps: 0.100
# | agent_1 -> mean_ep_rew | -24.39 | loss: 0.1873 | eps: 0.100
# | agent_2 -> mean_ep_rew | -24.34 | loss: 0.1000 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1300
# |    fps              | 256
# |    time_elapsed     | 126
# |    total_timesteps  | 32500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -24.51 | loss: 0.1424 | eps: 0.100
# | agent_1 -> mean_ep_rew | -24.45 | loss: 0.1732 | eps: 0.100
# | agent_2 -> mean_ep_rew | -24.44 | loss: 0.1656 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1400
# |    fps              | 252
# |    time_elapsed     | 138
# |    total_timesteps  | 35000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -23.94 | loss: 0.1104 | eps: 0.100
# | agent_1 -> mean_ep_rew | -23.93 | loss: 0.2359 | eps: 0.100
# | agent_2 -> mean_ep_rew | -23.93 | loss: 0.1199 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1500
# |    fps              | 250
# |    time_elapsed     | 149
# |    total_timesteps  | 37500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -23.32 | loss: 0.2993 | eps: 0.100
# | agent_1 -> mean_ep_rew | -23.19 | loss: 0.1900 | eps: 0.100
# | agent_2 -> mean_ep_rew | -23.34 | loss: 0.1195 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1600
# |    fps              | 247
# |    time_elapsed     | 161
# |    total_timesteps  | 40000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -22.89 | loss: 0.1783 | eps: 0.100
# | agent_1 -> mean_ep_rew | -23.00 | loss: 0.2489 | eps: 0.100
# | agent_2 -> mean_ep_rew | -22.89 | loss: 0.3406 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1700
# |    fps              | 245
# |    time_elapsed     | 173
# |    total_timesteps  | 42500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -23.41 | loss: 0.0968 | eps: 0.100
# | agent_1 -> mean_ep_rew | -23.42 | loss: 0.1699 | eps: 0.100
# | agent_2 -> mean_ep_rew | -23.45 | loss: 0.1870 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1800
# |    fps              | 242
# |    time_elapsed     | 185
# |    total_timesteps  | 45000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -21.70 | loss: 0.2887 | eps: 0.100
# | agent_1 -> mean_ep_rew | -21.57 | loss: 0.1168 | eps: 0.100
# | agent_2 -> mean_ep_rew | -21.56 | loss: 0.1528 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 1900
# |    fps              | 240
# |    time_elapsed     | 197
# |    total_timesteps  | 47500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.80 | loss: 0.2707 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.86 | loss: 0.1259 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.83 | loss: 0.1192 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2000
# |    fps              | 239
# |    time_elapsed     | 209
# |    total_timesteps  | 50000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.76 | loss: 0.1445 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.87 | loss: 0.1395 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.93 | loss: 0.1117 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2100
# |    fps              | 238
# |    time_elapsed     | 220
# |    total_timesteps  | 52500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -21.45 | loss: 0.3325 | eps: 0.100
# | agent_1 -> mean_ep_rew | -21.62 | loss: 0.2303 | eps: 0.100
# | agent_2 -> mean_ep_rew | -21.52 | loss: 0.4749 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2200
# |    fps              | 236
# |    time_elapsed     | 232
# |    total_timesteps  | 55000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.46 | loss: 0.3541 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.44 | loss: 0.3489 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.27 | loss: 0.2256 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2300
# |    fps              | 235
# |    time_elapsed     | 244
# |    total_timesteps  | 57500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.53 | loss: 0.3562 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.41 | loss: 0.3048 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.27 | loss: 0.2022 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2400
# |    fps              | 233
# |    time_elapsed     | 256
# |    total_timesteps  | 60000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.48 | loss: 0.1319 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.47 | loss: 0.1859 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.22 | loss: 0.2868 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2500
# |    fps              | 232
# |    time_elapsed     | 269
# |    total_timesteps  | 62500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.33 | loss: 0.3074 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.40 | loss: 0.1668 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.13 | loss: 0.1440 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2600
# |    fps              | 231
# |    time_elapsed     | 281
# |    total_timesteps  | 65000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.34 | loss: 0.5264 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.72 | loss: 0.2527 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.44 | loss: 0.2514 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2700
# |    fps              | 230
# |    time_elapsed     | 292
# |    total_timesteps  | 67500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.55 | loss: 0.0985 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.58 | loss: 0.2273 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.44 | loss: 0.5187 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2800
# |    fps              | 229
# |    time_elapsed     | 304
# |    total_timesteps  | 70000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.02 | loss: 0.3485 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.27 | loss: 0.3276 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.01 | loss: 0.1338 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 2900
# |    fps              | 228
# |    time_elapsed     | 317
# |    total_timesteps  | 72500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.77 | loss: 0.5124 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.82 | loss: 0.2528 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.80 | loss: 0.2605 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3000
# |    fps              | 226
# |    time_elapsed     | 330
# |    total_timesteps  | 75000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -21.05 | loss: 0.3593 | eps: 0.100
# | agent_1 -> mean_ep_rew | -21.11 | loss: 0.0921 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.97 | loss: 0.1118 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3100
# |    fps              | 225
# |    time_elapsed     | 344
# |    total_timesteps  | 77500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.57 | loss: 0.3890 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.41 | loss: 0.6676 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.37 | loss: 0.4230 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3200
# |    fps              | 224
# |    time_elapsed     | 355
# |    total_timesteps  | 80000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.08 | loss: 0.5041 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.34 | loss: 0.4913 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.04 | loss: 0.1825 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3300
# |    fps              | 224
# |    time_elapsed     | 367
# |    total_timesteps  | 82500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -21.04 | loss: 0.7342 | eps: 0.100
# | agent_1 -> mean_ep_rew | -21.24 | loss: 0.3665 | eps: 0.100
# | agent_2 -> mean_ep_rew | -21.10 | loss: 0.1854 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3400
# |    fps              | 224
# |    time_elapsed     | 379
# |    total_timesteps  | 85000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.39 | loss: 0.2242 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.34 | loss: 0.2788 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.43 | loss: 0.3312 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3500
# |    fps              | 223
# |    time_elapsed     | 390
# |    total_timesteps  | 87500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.35 | loss: 0.2383 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.30 | loss: 0.1691 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.17 | loss: 0.5934 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3600
# |    fps              | 223
# |    time_elapsed     | 402
# |    total_timesteps  | 90000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.59 | loss: 0.3444 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.69 | loss: 0.1410 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.65 | loss: 0.2860 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3700
# |    fps              | 223
# |    time_elapsed     | 414
# |    total_timesteps  | 92500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -21.07 | loss: 0.3271 | eps: 0.100
# | agent_1 -> mean_ep_rew | -21.31 | loss: 0.1584 | eps: 0.100
# | agent_2 -> mean_ep_rew | -21.31 | loss: 0.2957 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3800
# |    fps              | 222
# |    time_elapsed     | 426
# |    total_timesteps  | 95000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.87 | loss: 0.4681 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.99 | loss: 0.7351 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.60 | loss: 0.4030 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 3900
# |    fps              | 222
# |    time_elapsed     | 438
# |    total_timesteps  | 97500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.21 | loss: 0.4410 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.23 | loss: 0.3071 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.32 | loss: 0.4172 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 4000
# |    fps              | 222
# |    time_elapsed     | 450
# |    total_timesteps  | 100000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -21.85 | loss: 0.3232 | eps: 0.100
# | agent_1 -> mean_ep_rew | -22.05 | loss: 0.3342 | eps: 0.100
# | agent_2 -> mean_ep_rew | -21.98 | loss: 0.3229 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 4100
# |    fps              | 221
# |    time_elapsed     | 461
# |    total_timesteps  | 102500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.33 | loss: 0.1841 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.43 | loss: 0.2425 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.42 | loss: 0.6264 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 4200
# |    fps              | 221
# |    time_elapsed     | 473
# |    total_timesteps  | 105000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.84 | loss: 0.3462 | eps: 0.100
# | agent_1 -> mean_ep_rew | -21.13 | loss: 0.3385 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.56 | loss: 0.4595 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 4300
# |    fps              | 221
# |    time_elapsed     | 485
# |    total_timesteps  | 107500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.08 | loss: 0.3839 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.38 | loss: 0.5604 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.38 | loss: 0.6847 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 4400
# |    fps              | 221
# |    time_elapsed     | 497
# |    total_timesteps  | 110000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.93 | loss: 0.4524 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.96 | loss: 0.1974 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.96 | loss: 0.5009 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 4500
# |    fps              | 220
# |    time_elapsed     | 509
# |    total_timesteps  | 112500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.90 | loss: 0.6076 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.00 | loss: 0.3022 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.82 | loss: 0.6792 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 4600
# |    fps              | 220
# |    time_elapsed     | 520
# |    total_timesteps  | 115000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.06 | loss: 0.8054 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.18 | loss: 0.1250 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.22 | loss: 0.2830 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 4700
# |    fps              | 220
# |    time_elapsed     | 533
# |    total_timesteps  | 117500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.02 | loss: 0.2195 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.13 | loss: 0.2332 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.02 | loss: 0.8806 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 4800
# |    fps              | 220
# |    time_elapsed     | 545
# |    total_timesteps  | 120000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.82 | loss: 0.4674 | eps: 0.100
# | agent_1 -> mean_ep_rew | -21.00 | loss: 0.4032 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.80 | loss: 0.3567 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 4900
# |    fps              | 219
# |    time_elapsed     | 557
# |    total_timesteps  | 122500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.43 | loss: 0.4365 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.70 | loss: 0.2799 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.83 | loss: 0.8469 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 5000
# |    fps              | 219
# |    time_elapsed     | 570
# |    total_timesteps  | 125000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.96 | loss: 0.5645 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.96 | loss: 0.3829 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.84 | loss: 0.6075 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 5100
# |    fps              | 218
# |    time_elapsed     | 582
# |    total_timesteps  | 127500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.90 | loss: 0.5234 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.83 | loss: 0.3757 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.12 | loss: 0.6113 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 5200
# |    fps              | 218
# |    time_elapsed     | 594
# |    total_timesteps  | 130000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.45 | loss: 0.3404 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.48 | loss: 0.3761 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.61 | loss: 0.2331 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 5300
# |    fps              | 218
# |    time_elapsed     | 606
# |    total_timesteps  | 132500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.08 | loss: 0.2328 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.24 | loss: 0.4558 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.00 | loss: 0.4412 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 5400
# |    fps              | 218
# |    time_elapsed     | 618
# |    total_timesteps  | 135000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.45 | loss: 0.6254 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.54 | loss: 0.5312 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.63 | loss: 0.5978 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 5500
# |    fps              | 217
# |    time_elapsed     | 631
# |    total_timesteps  | 137500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.19 | loss: 0.4652 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.37 | loss: 0.8588 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.18 | loss: 0.3665 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 5600
# |    fps              | 217
# |    time_elapsed     | 644
# |    total_timesteps  | 140000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -18.77 | loss: 0.8757 | eps: 0.100
# | agent_1 -> mean_ep_rew | -18.86 | loss: 0.2086 | eps: 0.100
# | agent_2 -> mean_ep_rew | -18.91 | loss: 0.2842 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 5700
# |    fps              | 216
# |    time_elapsed     | 657
# |    total_timesteps  | 142500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -20.09 | loss: 0.7574 | eps: 0.100
# | agent_1 -> mean_ep_rew | -20.16 | loss: 0.7302 | eps: 0.100
# | agent_2 -> mean_ep_rew | -20.09 | loss: 0.5207 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 5800
# |    fps              | 216
# |    time_elapsed     | 669
# |    total_timesteps  | 145000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -18.17 | loss: 0.4655 | eps: 0.100
# | agent_1 -> mean_ep_rew | -18.31 | loss: 0.7444 | eps: 0.100
# | agent_2 -> mean_ep_rew | -18.59 | loss: 0.3368 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 5900
# |    fps              | 216
# |    time_elapsed     | 682
# |    total_timesteps  | 147500
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -18.37 | loss: 0.2428 | eps: 0.100
# | agent_1 -> mean_ep_rew | -18.44 | loss: 0.9778 | eps: 0.100
# | agent_2 -> mean_ep_rew | -18.53 | loss: 0.5509 | eps: 0.100
# ----------------------------------
# ----------------------------------
# | time/               |          |
# |    episodes         | 6000
# |    fps              | 215
# |    time_elapsed     | 694
# |    total_timesteps  | 150000
# |    ep_len_mean      | 25
# | agent_0 -> mean_ep_rew | -19.66 | loss: 0.7891 | eps: 0.100
# | agent_1 -> mean_ep_rew | -19.74 | loss: 0.5637 | eps: 0.100
# | agent_2 -> mean_ep_rew | -19.71 | loss: 0.6535 | eps: 0.100
# ----------------------------------

# %%
plot_total_rewards(episode_rewards4)
plot_total_rewards(episode_losses4)  # Graficar las pérdidas por episodio
rewards_4 = evaluate_agent_parallel(env, agent_dict, episodes=20)
plot_total_rewards(rewards_4)

# %%
evaluate_multiagent_render_parallel(agent_dict, env, num_tests=5, save_path="multiagent_episode_3_obstacles.mp4", fps=5, max_steps=50)
# Out:
# Video guardado en: multiagent_episode_3_obstacles.mp4
